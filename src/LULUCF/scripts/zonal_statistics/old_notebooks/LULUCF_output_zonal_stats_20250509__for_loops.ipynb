# %%
import coiled

import fsspec
import numpy as np
import rioxarray
import xarray as xr
import fsspec
import pandas as pd
import logging
from flox.xarray import xarray_reduce
import numpy as np
import dask
import re
import sparse
import time
from dask.distributed import Client, LocalCluster
from dask.distributed import print
from flox import ReindexArrayType, ReindexStrategy

import pygwalker as pyg

# Downloaded flox 0.10.3 from https://pypi.org/project/flox/#files usin the source distribution (tar.gz, https://files.pythonhosted.org/packages/0b/b6/5e3d79ef8e3dd3bb1ba656167e2059c0aa000244321995c508db32c7a578/flox-0.10.3.tar.gz)
# Installed in my working conda environment using pip: pip install /home/dagibbs22/flox-0.10.3.tar.gz

# %%
logging.getLogger("distributed.client").setLevel(logging.ERROR)

# %%
fs = fsspec.filesystem("s3", requester_pays=True)

# %%
cluster = coiled.Cluster(
    name="LULUCF_zonal_stats",
    region="us-east-1", # close to dataset, avoid egress charges
    n_workers=30,
    tags={"project": "AFOLU_flux_model"},
    scheduler_vm_types="r5.2xlarge", # memory optimized AWS EC2 instances
    worker_vm_types="r5.2xlarge",
    compute_purchase_option="spot_with_fallback"
)

client = cluster.get_client()

# %%
client.restart()

# %%
local_cluster = LocalCluster()  
local_client = Client(local_cluster)
local_client
# Out:
# <Client: 'tcp://127.0.0.1:38943' processes=7 threads=14, memory=31.08 GiB>

# %%
local_client.shutdown()

# %%
# Test of explicit uri listing

model_version = "version_0_3_2"
output_path = f"s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/{model_version}/"
run_date = "20250507"
interval = "2015_2016"

gross_emis_CO2_2016_tile_uri = pd.Series([f"{output_path}gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/{interval}/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_{interval}.tif",
                                          f"{output_path}gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/{interval}/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-5_24_-4__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_{interval}.tif",
                                          f"{output_path}gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/{interval}/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-4_25_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_{interval}.tif",
                                          f"{output_path}gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/{interval}/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-5_25_-4__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_{interval}.tif"], 
                                         name = 'emis_all_C_pools_CO2_only')
gross_emis_all_gases_2016_tile_uri = pd.Series([f"{output_path}gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/{interval}/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_{interval}.tif",
                                           f"{output_path}gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/{interval}/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-5_24_-4__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_{interval}.tif",
                                           f"{output_path}gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/{interval}/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-4_25_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_{interval}.tif",
                                           f"{output_path}gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/{interval}/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-5_25_-4__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_{interval}.tif"], 
                                         name = 'emis_all_C_pools_all_gases')
nodes_2016_tile_uri = pd.Series([f"{output_path}land_state_node/standard_model/annual_intervals/{interval}/4000_pixels/{run_date}/00N_020E__23_-4_24_-3__land_state_node_{interval}.tif",
                           f"{output_path}land_state_node/standard_model/annual_intervals/{interval}/4000_pixels/{run_date}/00N_020E__23_-5_24_-4__land_state_node_{interval}.tif",
                           f"{output_path}land_state_node/standard_model/annual_intervals/{interval}/4000_pixels/{run_date}/00N_020E__24_-4_25_-3__land_state_node_{interval}.tif",
                           f"{output_path}land_state_node/standard_model/annual_intervals/{interval}/4000_pixels/{run_date}/00N_020E__24_-5_25_-4__land_state_node_{interval}.tif"], 
                          name = 'node_codes')
print(gross_emis_CO2_2016_tile_uri)
# print(gross_emis_all_gases_2016_tile_uri)
# print(nodes_2016_tile_uri)
# print(type(gross_emis_CO2_2016_tile_uri))
# Out:
# 0    s3://gfw2-data/climate/AFOLU_flux_model/LULUCF...
# 1    s3://gfw2-data/climate/AFOLU_flux_model/LULUCF...
# 2    s3://gfw2-data/climate/AFOLU_flux_model/LULUCF...
# 3    s3://gfw2-data/climate/AFOLU_flux_model/LULUCF...
# Name: emis_all_C_pools_CO2_only, dtype: object

# %%
# uri components

model_version = "version_0_3_2"
run_date = "20250507"
output_path = f"s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/{model_version}/"
# interval_end_years = [2016]
# interval_end_years = [2016, 2017, 2018]
# interval_end_years = [2020]
interval_end_years = [2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

# %%
# Node codes output from model. Covers entire decision tree. Make sure that node codes are right-padded with 0s to 7 digits! 
# Otherwise, only the node codes that are seven digits without 0s will be matched with the node code rasters and output. 
# TODO: I may have accidentally missed some node codes when copying them from the decision tree. Check!
node_codes = np.array([
    1110000, 1120000, 1210000, 1220000, 2111000, 2112000,
    2121100, 2121200, 2122100, 2122200, 2123100, 2123200,
    2124100, 2124200, 2125100, 2125200, 2211100, 2211200, 2212110, 2212120, 
    2212210, 2212220, 2213110, 2213120, 2213210, 2213220,
    2214100, 2214200, 2215100, 2215200, 2221100, 2221200, 2223100, 2223200,
    2222100, 2222200, 3110000, 3120000, 3211211, 3211212,
    3211221, 3211222, 3212111, 3212112, 3212121, 3212122,
    3212211, 3212212, 3212221, 3212222, 3221110, 3221120,
    3221210, 3221220, 3222111, 3222112, 3222121, 3222122,
    3222210, 3222220, 4100000, 4210000, 4220000, 4310000,
    4320000, 5100000, 5210000, 5220000, 5310000, 5320000],
dtype=np.uint32)

# # Node codes output from model for 2x2 test area in DRC (23_-5_25_-3)
# node_codes = np.array([3222111, 2212120, 3222121, 3212122, 2212110, 3212121, 3222210, 2223200, 
#                        2221200, 3212222, 2221100, 5220000, 4100000, 2223100,
#                        2212220, 3212221, 2211200, 5210000, 2211100, 4220000, 2212210, 2214100, 2214200, 4210000, 2215200], 
#                       dtype=np.uint32)

# %%
# Extracts some metadata/chunk properties to add to the output dataframe
def parse_metadata_from_uri(uri_series):

    uri = uri_series.values.tolist()[0]
    # print("Parsing URI:", uri)

    # regex per https://chatgpt.com/g/g-vK4oPfjfp-coding-assistant/c/681a538d-55e4-800a-818b-bcf850757ba0
    pattern = r"__(\d+_-?\d+_\d+_-?\d+)__([a-zA-Z0-9_]+(?:__?[a-zA-Z0-9_]+)*)_pixel_yr_(\d{4}_\d{4})\.tif$"
    match = re.search(pattern, uri)

    if match:
        chunk_id = match.group(1)
        variable = match.group(2)
        interval = match.group(3)
    else:
        interval, chunk_id, variable = None, None, None

    return interval, chunk_id, variable

# %%
def make_xarray_chunks(tile_uris):

    xarray_chunks = xr.open_mfdataset(
        tile_uris.values.tolist(),
        parallel=True,
        chunks={'x': 2000, 'y':2000}
    ).squeeze().persist()

    return xarray_chunks

# %%
def align_with_nodes(analysis_layer, nodes):
    analysis_layer_sub, nodes_aligned = xr.align(analysis_layer, nodes, join="inner")
    return analysis_layer_sub, nodes_aligned

# %%
# reduction using sum and count from https://chatgpt.com/g/g-vK4oPfjfp-coding-assistant/c/6821fa2d-d658-800a-a371-aaa570dac95c
def xarray_reduction_sum_count(analysis_layer, node_data):

    reductions = {}

    for func in ["sum", "count"]:
        reduced = xarray_reduce(
            analysis_layer.band_data,
            node_data,
            func=func,
            keep_attrs=True,
            expected_groups=(node_codes),
            reindex=ReindexStrategy(
                blockwise=False,
                array_type=ReindexArrayType.SPARSE_COO
            ),
            fill_value=0
        )

        # Rename variables to reflect reduction type
        if isinstance(reduced, xr.Dataset):
            renamed = reduced.rename({var: f"{var}_{func}" for var in reduced.data_vars})
        else:  # it's a DataArray
            renamed = reduced.rename(f"{reduced.name}_{func}")

        reductions[func] = renamed

    # Merge results: handle Dataset or DataArray combinations
    result = xr.merge([r if isinstance(r, xr.Dataset) else r.to_dataset() for r in reductions.values()])

    return result

# %%
def xarray_reduction(analysis_layer, node_data):

    analysis_layer_by_node = xarray_reduce(
        analysis_layer.band_data,
        node_data,
        func='sum',
        keep_attrs=True,
        expected_groups=(node_codes),
        reindex=ReindexStrategy(
            blockwise=False, array_type=ReindexArrayType.SPARSE_COO
        ),
        fill_value=0   
    )

    return analysis_layer_by_node

# %%
def create_output_year_df(output_year_result, interval, ouput_pattern):

    output_year_result_sparse_data = output_year_result.data

    # Step 3: Extract coordinates and values
    dim_names = output_year_result.dims
    indices = output_year_result_sparse_data.coords
    output_year_values = output_year_result_sparse_data.data

    # Step 4: Map dimension indices to coordinate values
    output_year_coord_dict = {
        dim: output_year_result.coords[dim].values[indices[i]]
        for i, dim in enumerate(dim_names)
    }
    output_year_coord_dict["value"] = output_year_values
    
    output_year_coord_dict = {
        dim: output_year_result.coords[dim].values[indices[i]]
        for i, dim in enumerate(dim_names)
    }
    output_year_coord_dict["value"] = output_year_values
    
    output_year_df = pd.DataFrame(output_year_coord_dict)

    output_year_df["interval_end"] = interval
    output_year_df["output_pattern"] = ouput_pattern

    return output_year_df

# %%
# Reclassifies state nodes to broad categories
def classify_node(state_node):
    
    node_str = str(state_node)
    first_digit = int(node_str[0])
    # print(first_digit)

    # For broad classes that can be categorized using just the first digit
    one_digit_map = {
        1: 'forest_gain',
        2: 'forest_loss',
        4: 'cropland',
        5: 'grassland'
    }

    # For broad classes that need to be categorized using the first three digits
    three_digit_map = {
        321: 'disturbed_forest',
        322: 'stable_forest'
        # Add more as needed
    }
    
    if first_digit == 3:
        prefix = int(node_str[:3])
        # print(prefix)
        # print(two_digit_map.get(prefix, 'unknown_3x'))
        return three_digit_map.get(prefix, 'unknown_3x')
    else:
        return one_digit_map.get(first_digit, 'unknown')

# %% [markdown]
# Code to run zonal stats

# %%
# uris for inputs, with placeholders for interval that are filled in as intervals are iterated through

gross_emis_CO2_tile_uris = pd.Series([f"{output_path}gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_INTERVAL.tif",
                                          f"{output_path}gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-5_24_-4__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_INTERVAL.tif",
                                          f"{output_path}gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-4_25_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_INTERVAL.tif",
                                          f"{output_path}gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-5_25_-4__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_INTERVAL.tif"])
gross_emis_all_gases_tile_uris = pd.Series([f"{output_path}gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_INTERVAL.tif",
                                           f"{output_path}gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-5_24_-4__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_INTERVAL.tif",
                                           f"{output_path}gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-4_25_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_INTERVAL.tif",
                                           f"{output_path}gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-5_25_-4__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_INTERVAL.tif"])
gross_remv_all_pools_tile_uris = pd.Series([f"{output_path}gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-4_24_-3__gross_removals__all_C_pools__MgCO2_pixel_yr_INTERVAL.tif",
                                           f"{output_path}gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-5_24_-4__gross_removals__all_C_pools__MgCO2_pixel_yr_INTERVAL.tif",
                                           f"{output_path}gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-4_25_-3__gross_removals__all_C_pools__MgCO2_pixel_yr_INTERVAL.tif",
                                           f"{output_path}gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-5_25_-4__gross_removals__all_C_pools__MgCO2_pixel_yr_INTERVAL.tif"])
net_flux_all_pools_CO2_tile_uris = pd.Series([f"{output_path}net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-4_24_-3__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_INTERVAL.tif",
                                           f"{output_path}net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__23_-5_24_-4__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_INTERVAL.tif",
                                           f"{output_path}net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-4_25_-3__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_INTERVAL.tif",
                                           f"{output_path}net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/INTERVAL/_pixel_yr/4000_pixels/{run_date}/00N_020E__24_-5_25_-4__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_INTERVAL.tif"])

node_tile_uris = pd.Series([f"{output_path}land_state_node/standard_model/annual_intervals/INTERVAL/4000_pixels/{run_date}/00N_020E__23_-4_24_-3__land_state_node_INTERVAL.tif",
                           f"{output_path}land_state_node/standard_model/annual_intervals/INTERVAL/4000_pixels/{run_date}/00N_020E__23_-5_24_-4__land_state_node_INTERVAL.tif",
                           f"{output_path}land_state_node/standard_model/annual_intervals/INTERVAL/4000_pixels/{run_date}/00N_020E__24_-4_25_-3__land_state_node_INTERVAL.tif",
                           f"{output_path}land_state_node/standard_model/annual_intervals/INTERVAL/4000_pixels/{run_date}/00N_020E__24_-5_25_-4__land_state_node_INTERVAL.tif"])

# %%
analysis_layers_uris = [gross_emis_CO2_tile_uris, gross_emis_all_gases_tile_uris, gross_remv_all_pools_tile_uris, net_flux_all_pools_CO2_tile_uris]
# analysis_layers_uris = [net_flux_all_pools_CO2_tile_uris]


combined_df = pd.DataFrame()
analysis_start_time = time.time()

for focal_analysis_layer_uris in analysis_layers_uris:

    layer_start_time = time.time()

    for interval_end_year in interval_end_years:

        interval = f"{interval_end_year-1}_{interval_end_year}"
        # print(interval)

        focal_analysis_layer_year_uris = focal_analysis_layer_uris.str.replace("INTERVAL", interval, regex=False)
        # print(focal_analysis_layer_year_uris)

        node_tile_year_uris = node_tile_uris.str.replace("INTERVAL", interval, regex=False)

        interval_from_inputs, chunk_id, output_pattern = parse_metadata_from_uri(focal_analysis_layer_year_uris)
        # print(output_pattern)
    
        print(f"Processing {(output_pattern)} for {interval} from {focal_analysis_layer_year_uris[0]}")
        layer_interval_start_time = time.time()
    
        layer_xarray_chunks = make_xarray_chunks(focal_analysis_layer_year_uris)
        node_xarray_chunks = make_xarray_chunks(node_tile_year_uris)
        print("layer_xarray_chunks:", layer_xarray_chunks)
        print("node_xarray_chunks:", node_xarray_chunks)
        
        layer_sub, nodes_aligned = align_with_nodes(layer_xarray_chunks, node_xarray_chunks)
        # print("layer_sub:", layer_sub)
        # print("nodes_aligned:", nodes_aligned)
        
        node_data = nodes_aligned.band_data
        node_data.name = 'state_node'
        # print("node_data", node_data)

        print(f"   Reducing {(output_pattern)} for {interval}")
        
        analysis_layer_by_node = xarray_reduction(layer_sub, node_data)
        # analysis_layer_by_node = xarray_reduction_sum_count(layer_sub, node_data)
        # print("analysis_layer_by_node:", analysis_layer_by_node)

        print(f"   Computing {(output_pattern)} for {interval}")
        
        analysis_layer_result = analysis_layer_by_node.compute()
        # print(analysis_layer_result)

        print(f"   Creating and concatenating dataframe for {(output_pattern)} for {interval}")
        
        output_year_df = create_output_year_df(analysis_layer_result, interval_end_year, output_pattern)
        # print(output_year_df)
    
        combined_df = pd.concat([combined_df, output_year_df])

        layer_interval_end_time = time.time()
        print(f"   {(output_pattern)} for {interval} took {round(layer_interval_end_time - layer_interval_start_time)} seconds")

    layer_end_time = time.time()
    print(f"-----{(output_pattern)} for all {len(interval_end_years)} intervals took {round(layer_end_time - layer_start_time)} seconds")
    print("")

combined_df = combined_df.reset_index(drop=True)
analysis_end_time = time.time()
print(f"Analysis took {round(analysis_end_time - analysis_start_time)} seconds")
combined_df['node_grp'] = combined_df['state_node'].apply(classify_node)
combined_df['state_node'] = 'n' + combined_df['state_node'].astype(str)
combined_df
# Out:
# Processing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2015_2016 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2015_2016/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_2015_2016.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2015_2016
#    Computing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2015_2016
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__CO2_only__MgCO2 for 2015_2016
#    gross_emissions__all_C_pools__CO2_only__MgCO2 for 2015_2016 took 8 seconds
# Processing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2016_2017 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2016_2017/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_2016_2017.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2016_2017
#    Computing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2016_2017
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__CO2_only__MgCO2 for 2016_2017
#    gross_emissions__all_C_pools__CO2_only__MgCO2 for 2016_2017 took 8 seconds
# Processing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2017_2018 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2017_2018/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_2017_2018.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2017_2018
#    Computing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2017_2018
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__CO2_only__MgCO2 for 2017_2018
#    gross_emissions__all_C_pools__CO2_only__MgCO2 for 2017_2018 took 14 seconds
# Processing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2018_2019 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2018_2019/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_2018_2019.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2018_2019
#    Computing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2018_2019
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__CO2_only__MgCO2 for 2018_2019
#    gross_emissions__all_C_pools__CO2_only__MgCO2 for 2018_2019 took 14 seconds
# Processing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2019_2020 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2019_2020/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_2019_2020.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2019_2020
#    Computing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2019_2020
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__CO2_only__MgCO2 for 2019_2020
#    gross_emissions__all_C_pools__CO2_only__MgCO2 for 2019_2020 took 11 seconds
# Processing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2020_2021 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2020_2021/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_2020_2021.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2020_2021
#    Computing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2020_2021
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__CO2_only__MgCO2 for 2020_2021
#    gross_emissions__all_C_pools__CO2_only__MgCO2 for 2020_2021 took 14 seconds
# Processing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2021_2022 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2021_2022/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_2021_2022.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2021_2022
#    Computing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2021_2022
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__CO2_only__MgCO2 for 2021_2022
#    gross_emissions__all_C_pools__CO2_only__MgCO2 for 2021_2022 took 8 seconds
# Processing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2022_2023 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2022_2023/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__CO2_only__MgCO2_pixel_yr_2022_2023.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2022_2023
#    Computing gross_emissions__all_C_pools__CO2_only__MgCO2 for 2022_2023
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__CO2_only__MgCO2 for 2022_2023
#    gross_emissions__all_C_pools__CO2_only__MgCO2 for 2022_2023 took 14 seconds
# -----gross_emissions__all_C_pools__CO2_only__MgCO2 for all 8 intervals took 90 seconds
#
# Processing gross_emissions__all_C_pools__all_gases__MgCO2e for 2015_2016 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/2015_2016/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_2015_2016.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__all_gases__MgCO2e for 2015_2016
#    Computing gross_emissions__all_C_pools__all_gases__MgCO2e for 2015_2016
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__all_gases__MgCO2e for 2015_2016
#    gross_emissions__all_C_pools__all_gases__MgCO2e for 2015_2016 took 13 seconds
# Processing gross_emissions__all_C_pools__all_gases__MgCO2e for 2016_2017 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/2016_2017/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_2016_2017.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__all_gases__MgCO2e for 2016_2017
#    Computing gross_emissions__all_C_pools__all_gases__MgCO2e for 2016_2017
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__all_gases__MgCO2e for 2016_2017
#    gross_emissions__all_C_pools__all_gases__MgCO2e for 2016_2017 took 8 seconds
# Processing gross_emissions__all_C_pools__all_gases__MgCO2e for 2017_2018 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/2017_2018/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_2017_2018.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__all_gases__MgCO2e for 2017_2018
#    Computing gross_emissions__all_C_pools__all_gases__MgCO2e for 2017_2018
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__all_gases__MgCO2e for 2017_2018
#    gross_emissions__all_C_pools__all_gases__MgCO2e for 2017_2018 took 11 seconds
# Processing gross_emissions__all_C_pools__all_gases__MgCO2e for 2018_2019 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/2018_2019/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_2018_2019.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__all_gases__MgCO2e for 2018_2019
#    Computing gross_emissions__all_C_pools__all_gases__MgCO2e for 2018_2019
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__all_gases__MgCO2e for 2018_2019
#    gross_emissions__all_C_pools__all_gases__MgCO2e for 2018_2019 took 10 seconds
# Processing gross_emissions__all_C_pools__all_gases__MgCO2e for 2019_2020 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/2019_2020/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_2019_2020.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__all_gases__MgCO2e for 2019_2020
#    Computing gross_emissions__all_C_pools__all_gases__MgCO2e for 2019_2020
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__all_gases__MgCO2e for 2019_2020
#    gross_emissions__all_C_pools__all_gases__MgCO2e for 2019_2020 took 17 seconds
# Processing gross_emissions__all_C_pools__all_gases__MgCO2e for 2020_2021 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/2020_2021/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_2020_2021.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__all_gases__MgCO2e for 2020_2021
#    Computing gross_emissions__all_C_pools__all_gases__MgCO2e for 2020_2021
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__all_gases__MgCO2e for 2020_2021
#    gross_emissions__all_C_pools__all_gases__MgCO2e for 2020_2021 took 12 seconds
# Processing gross_emissions__all_C_pools__all_gases__MgCO2e for 2021_2022 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/2021_2022/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_2021_2022.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__all_gases__MgCO2e for 2021_2022
#    Computing gross_emissions__all_C_pools__all_gases__MgCO2e for 2021_2022
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__all_gases__MgCO2e for 2021_2022
#    gross_emissions__all_C_pools__all_gases__MgCO2e for 2021_2022 took 11 seconds
# Processing gross_emissions__all_C_pools__all_gases__MgCO2e for 2022_2023 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_emissions__all_C_pools__all_gases__MgCO2e/standard_model/annual_intervals/2022_2023/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_emissions__all_C_pools__all_gases__MgCO2e_pixel_yr_2022_2023.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_emissions__all_C_pools__all_gases__MgCO2e for 2022_2023
#    Computing gross_emissions__all_C_pools__all_gases__MgCO2e for 2022_2023
#    Creating and concatenating dataframe for gross_emissions__all_C_pools__all_gases__MgCO2e for 2022_2023
#    gross_emissions__all_C_pools__all_gases__MgCO2e for 2022_2023 took 10 seconds
# -----gross_emissions__all_C_pools__all_gases__MgCO2e for all 8 intervals took 93 seconds
#
# Processing gross_removals__all_C_pools__MgCO2 for 2015_2016 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/2015_2016/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_removals__all_C_pools__MgCO2_pixel_yr_2015_2016.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_removals__all_C_pools__MgCO2 for 2015_2016
#    Computing gross_removals__all_C_pools__MgCO2 for 2015_2016
#    Creating and concatenating dataframe for gross_removals__all_C_pools__MgCO2 for 2015_2016
#    gross_removals__all_C_pools__MgCO2 for 2015_2016 took 17 seconds
# Processing gross_removals__all_C_pools__MgCO2 for 2016_2017 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/2016_2017/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_removals__all_C_pools__MgCO2_pixel_yr_2016_2017.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_removals__all_C_pools__MgCO2 for 2016_2017
#    Computing gross_removals__all_C_pools__MgCO2 for 2016_2017
#    Creating and concatenating dataframe for gross_removals__all_C_pools__MgCO2 for 2016_2017
#    gross_removals__all_C_pools__MgCO2 for 2016_2017 took 18 seconds
# Processing gross_removals__all_C_pools__MgCO2 for 2017_2018 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/2017_2018/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_removals__all_C_pools__MgCO2_pixel_yr_2017_2018.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_removals__all_C_pools__MgCO2 for 2017_2018
#    Computing gross_removals__all_C_pools__MgCO2 for 2017_2018
#    Creating and concatenating dataframe for gross_removals__all_C_pools__MgCO2 for 2017_2018
#    gross_removals__all_C_pools__MgCO2 for 2017_2018 took 18 seconds
# Processing gross_removals__all_C_pools__MgCO2 for 2018_2019 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/2018_2019/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_removals__all_C_pools__MgCO2_pixel_yr_2018_2019.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_removals__all_C_pools__MgCO2 for 2018_2019
#    Computing gross_removals__all_C_pools__MgCO2 for 2018_2019
#    Creating and concatenating dataframe for gross_removals__all_C_pools__MgCO2 for 2018_2019
#    gross_removals__all_C_pools__MgCO2 for 2018_2019 took 20 seconds
# Processing gross_removals__all_C_pools__MgCO2 for 2019_2020 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/2019_2020/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_removals__all_C_pools__MgCO2_pixel_yr_2019_2020.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_removals__all_C_pools__MgCO2 for 2019_2020
#    Computing gross_removals__all_C_pools__MgCO2 for 2019_2020
#    Creating and concatenating dataframe for gross_removals__all_C_pools__MgCO2 for 2019_2020
#    gross_removals__all_C_pools__MgCO2 for 2019_2020 took 20 seconds
# Processing gross_removals__all_C_pools__MgCO2 for 2020_2021 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/2020_2021/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_removals__all_C_pools__MgCO2_pixel_yr_2020_2021.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_removals__all_C_pools__MgCO2 for 2020_2021
#    Computing gross_removals__all_C_pools__MgCO2 for 2020_2021
#    Creating and concatenating dataframe for gross_removals__all_C_pools__MgCO2 for 2020_2021
#    gross_removals__all_C_pools__MgCO2 for 2020_2021 took 19 seconds
# Processing gross_removals__all_C_pools__MgCO2 for 2021_2022 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/2021_2022/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_removals__all_C_pools__MgCO2_pixel_yr_2021_2022.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_removals__all_C_pools__MgCO2 for 2021_2022
#    Computing gross_removals__all_C_pools__MgCO2 for 2021_2022
#    Creating and concatenating dataframe for gross_removals__all_C_pools__MgCO2 for 2021_2022
#    gross_removals__all_C_pools__MgCO2 for 2021_2022 took 20 seconds
# Processing gross_removals__all_C_pools__MgCO2 for 2022_2023 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/gross_removals__all_C_pools__MgCO2/standard_model/annual_intervals/2022_2023/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__gross_removals__all_C_pools__MgCO2_pixel_yr_2022_2023.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing gross_removals__all_C_pools__MgCO2 for 2022_2023
#    Computing gross_removals__all_C_pools__MgCO2 for 2022_2023
#    Creating and concatenating dataframe for gross_removals__all_C_pools__MgCO2 for 2022_2023
#    gross_removals__all_C_pools__MgCO2 for 2022_2023 took 17 seconds
# -----gross_removals__all_C_pools__MgCO2 for all 8 intervals took 150 seconds
#
# Processing net_flux__all_C_pools__CO2_only__MgCO2 for 2015_2016 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2015_2016/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_2015_2016.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing net_flux__all_C_pools__CO2_only__MgCO2 for 2015_2016
#    Computing net_flux__all_C_pools__CO2_only__MgCO2 for 2015_2016
#    Creating and concatenating dataframe for net_flux__all_C_pools__CO2_only__MgCO2 for 2015_2016
#    net_flux__all_C_pools__CO2_only__MgCO2 for 2015_2016 took 17 seconds
# Processing net_flux__all_C_pools__CO2_only__MgCO2 for 2016_2017 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2016_2017/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_2016_2017.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing net_flux__all_C_pools__CO2_only__MgCO2 for 2016_2017
#    Computing net_flux__all_C_pools__CO2_only__MgCO2 for 2016_2017
#    Creating and concatenating dataframe for net_flux__all_C_pools__CO2_only__MgCO2 for 2016_2017
#    net_flux__all_C_pools__CO2_only__MgCO2 for 2016_2017 took 21 seconds
# Processing net_flux__all_C_pools__CO2_only__MgCO2 for 2017_2018 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2017_2018/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_2017_2018.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing net_flux__all_C_pools__CO2_only__MgCO2 for 2017_2018
#    Computing net_flux__all_C_pools__CO2_only__MgCO2 for 2017_2018
#    Creating and concatenating dataframe for net_flux__all_C_pools__CO2_only__MgCO2 for 2017_2018
#    net_flux__all_C_pools__CO2_only__MgCO2 for 2017_2018 took 21 seconds
# Processing net_flux__all_C_pools__CO2_only__MgCO2 for 2018_2019 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2018_2019/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_2018_2019.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing net_flux__all_C_pools__CO2_only__MgCO2 for 2018_2019
#    Computing net_flux__all_C_pools__CO2_only__MgCO2 for 2018_2019
#    Creating and concatenating dataframe for net_flux__all_C_pools__CO2_only__MgCO2 for 2018_2019
#    net_flux__all_C_pools__CO2_only__MgCO2 for 2018_2019 took 21 seconds
# Processing net_flux__all_C_pools__CO2_only__MgCO2 for 2019_2020 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2019_2020/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_2019_2020.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing net_flux__all_C_pools__CO2_only__MgCO2 for 2019_2020
#    Computing net_flux__all_C_pools__CO2_only__MgCO2 for 2019_2020
#    Creating and concatenating dataframe for net_flux__all_C_pools__CO2_only__MgCO2 for 2019_2020
#    net_flux__all_C_pools__CO2_only__MgCO2 for 2019_2020 took 25 seconds
# Processing net_flux__all_C_pools__CO2_only__MgCO2 for 2020_2021 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2020_2021/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_2020_2021.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing net_flux__all_C_pools__CO2_only__MgCO2 for 2020_2021
#    Computing net_flux__all_C_pools__CO2_only__MgCO2 for 2020_2021
#    Creating and concatenating dataframe for net_flux__all_C_pools__CO2_only__MgCO2 for 2020_2021
#    net_flux__all_C_pools__CO2_only__MgCO2 for 2020_2021 took 21 seconds
# Processing net_flux__all_C_pools__CO2_only__MgCO2 for 2021_2022 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2021_2022/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_2021_2022.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing net_flux__all_C_pools__CO2_only__MgCO2 for 2021_2022
#    Computing net_flux__all_C_pools__CO2_only__MgCO2 for 2021_2022
#    Creating and concatenating dataframe for net_flux__all_C_pools__CO2_only__MgCO2 for 2021_2022
#    net_flux__all_C_pools__CO2_only__MgCO2 for 2021_2022 took 24 seconds
# Processing net_flux__all_C_pools__CO2_only__MgCO2 for 2022_2023 from s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/version_0_3_2/net_flux__all_C_pools__CO2_only__MgCO2/standard_model/annual_intervals/2022_2023/_pixel_yr/4000_pixels/20250507/00N_020E__23_-4_24_-3__net_flux__all_C_pools__CO2_only__MgCO2_pixel_yr_2022_2023.tif
# layer_xarray_chunks: <xarray.Dataset> Size: 256MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float32 256MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
# node_xarray_chunks: <xarray.Dataset> Size: 512MB
# Dimensions:      (y: 8000, x: 8000)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 64kB 23.0 23.0 23.0 23.0 ... 25.0 25.0 25.0 25.0
#   * y            (y) float64 64kB -3.0 -3.0 -3.001 -3.001 ... -4.999 -5.0 -5.0
#     spatial_ref  int64 8B 0
# Data variables:
#     band_data    (y, x) float64 512MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#    Reducing net_flux__all_C_pools__CO2_only__MgCO2 for 2022_2023
#    Computing net_flux__all_C_pools__CO2_only__MgCO2 for 2022_2023
#    Creating and concatenating dataframe for net_flux__all_C_pools__CO2_only__MgCO2 for 2022_2023
#    net_flux__all_C_pools__CO2_only__MgCO2 for 2022_2023 took 21 seconds
# -----net_flux__all_C_pools__CO2_only__MgCO2 for all 8 intervals took 171 seconds
#
# Analysis took 503 seconds
#     state_node         value  interval_end  \
# 0     n2211100  1.060868e+04          2016
# 1     n2211200  2.899860e+04          2016
# 2     n2212110  9.996288e+06          2016
# 3     n2212120  5.400350e+07          2016
# 4     n2212210  4.059757e+04          2016
# ..         ...           ...           ...
# 744   n4210000  1.639021e+02          2023
# 745   n4220000  1.586794e+02          2023
# 746   n5100000 -5.350347e+03          2023
# 747   n5210000  1.062209e+03          2023
# 748   n5220000  1.175207e+04          2023
#
#                                     output_pattern     node_grp
# 0    gross_emissions__all_C_pools__CO2_only__MgCO2  forest_loss
# 1    gross_emissions__all_C_pools__CO2_only__MgCO2  forest_loss
# 2    gross_emissions__all_C_pools__CO2_only__MgCO2  forest_loss
# 3    gross_emissions__all_C_pools__CO2_only__MgCO2  forest_loss
# 4    gross_emissions__all_C_pools__CO2_only__MgCO2  forest_loss
# ..                                             ...          ...
# 744         net_flux__all_C_pools__CO2_only__MgCO2     cropland
# 745         net_flux__all_C_pools__CO2_only__MgCO2     cropland
# 746         net_flux__all_C_pools__CO2_only__MgCO2    grassland
# 747         net_flux__all_C_pools__CO2_only__MgCO2    grassland
# 748         net_flux__all_C_pools__CO2_only__MgCO2    grassland
#
# [749 rows x 5 columns]

# %%
combined_df_wide = combined_df.pivot(index=['state_node', 'interval_end'], columns="output_pattern", values="value").reset_index()
combined_df_wide

# %%
combined_df.head()

# %%
# combined_df[(combined_df.state_node == 2212210)]
combined_df[(combined_df.interval_end == 2023)]

# %%
combined_df2 = combined_df

# %%
combined_df2['state_node'] = 'g' + combined_df2['state_node'].astype(str)
combined_df2
# Out:
#     state_node         value  interval_end  \
# 0    gg2211100  1.060868e+04          2016
# 1    gg2211200  2.899860e+04          2016
# 2    gg2212110  9.996288e+06          2016
# 3    gg2212120  5.400350e+07          2016
# 4    gg2212210  4.059757e+04          2016
# ..         ...           ...           ...
# 744  gg4210000  1.639021e+02          2023
# 745  gg4220000  1.586794e+02          2023
# 746  gg5100000 -5.350347e+03          2023
# 747  gg5210000  1.062209e+03          2023
# 748  gg5220000  1.175207e+04          2023
#
#                                     output_pattern     node_grp
# 0    gross_emissions__all_C_pools__CO2_only__MgCO2  forest_loss
# 1    gross_emissions__all_C_pools__CO2_only__MgCO2  forest_loss
# 2    gross_emissions__all_C_pools__CO2_only__MgCO2  forest_loss
# 3    gross_emissions__all_C_pools__CO2_only__MgCO2  forest_loss
# 4    gross_emissions__all_C_pools__CO2_only__MgCO2  forest_loss
# ..                                             ...          ...
# 744         net_flux__all_C_pools__CO2_only__MgCO2     cropland
# 745         net_flux__all_C_pools__CO2_only__MgCO2     cropland
# 746         net_flux__all_C_pools__CO2_only__MgCO2    grassland
# 747         net_flux__all_C_pools__CO2_only__MgCO2    grassland
# 748         net_flux__all_C_pools__CO2_only__MgCO2    grassland
#
# [749 rows x 5 columns]

# %%
combined_df2[(combined_df2.output_pattern == 'gross_emissions__all_C_pools__CO2_only__MgCO2') 
& (combined_df2.state_node == 'gg3222112')]
# Out:
# Empty DataFrame
# Columns: [state_node, value, interval_end, output_pattern, node_grp]
# Index: []

# %%
walker = pyg.walk(combined_df2)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-1" style="height: auto">\n    <head>\n        <meta http-equiv="Con…
