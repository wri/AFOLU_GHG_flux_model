# %% [markdown]
# <font size="6">Run the organic soils part of the AFOLU model</font>
#
# <font size="4">Must be run using the utilities_and_variables.ipynb kernel</font>

# %% [markdown]
# Got the no data working - but it isn't an elegant solution. Will come back to this with a better fix. Also - need to compress input datasets

# %%
import logging

# %%
# Set up basic configuration for logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
def save_and_upload_small_raster_set(bounds, chunk_length_pixels, tile_id, bounds_str, output_dict, is_final):
    s3_client = boto3.client("s3")  # Needs to be in the same function as the upload_file call

    transform = rasterio.transform.from_bounds(*bounds, width=chunk_length_pixels, height=chunk_length_pixels)

    file_info = f'{tile_id}__{bounds_str}'

    # For every output file, saves from array to local raster, then to s3.
    # Can't save directly to s3, unfortunately, so need to save locally first.
    for key, value in output_dict.items():
        logging.info(f"Processing output for key: {key}")
        try:
            data_array = value[0]
            data_type = value[1]
            data_meaning = value[2]
            year_out = value[3]

            logging.info(f"Data type: {data_type}, Data meaning: {data_meaning}, Year out: {year_out}")

            if not is_final:
                logging.info(f"Saving {bounds_str} in {tile_id} for {year_out}: {timestr()}")

            if is_final:
                file_name = f"{file_info}__{key}.tif"
            else:
                file_name = f"{file_info}__{key}__{timestr()}.tif"

            with rasterio.open(f"/tmp/{file_name}", 'w', driver='GTiff', width=chunk_length_pixels, height=chunk_length_pixels, count=1, 
                               dtype=data_type, crs='EPSG:4326', transform=transform, compress='lzw', blockxsize=400, blockysize=400) as dst:
                dst.write(data_array, 1)

            s3_path = f"{s3_out_dir}/{data_meaning}/{year_out}/{chunk_length_pixels}_pixels/{time.strftime('%Y%m%d')}"
            logging.info(f"Saving output to {s3_path}...")

            if not is_final:
                logging.info(f"Uploading {bounds_str} in {tile_id} for {year_out} to {s3_path}: {timestr()}")

            s3_client.upload_file(f"/tmp/{file_name}", "gfw2-data", Key=f"{s3_path}/{file_name}")

            # Deletes the local raster
            os.remove(f"/tmp/{file_name}")

            logging.info(f"Successfully processed and uploaded {file_name}")

        except Exception as e:
            logging.error(f"Error processing key {key} with value {value}: {str(e)}")

    logging.info(f"Completed processing for chunk {bounds_str}.")

# %%
def calculate_and_upload_drainage(bounds, is_final):
    bounds_str = boundstr(bounds)  # String form of chunk bounds
    tile_id = xy_to_tile_id(bounds[0], bounds[3])  # tile_id in YYN/S_XXXE/W
    chunk_length_pixels = calc_chunk_length_pixels(bounds)  # Chunk length in pixels (as opposed to decimal degrees)

    no_data_val = 255
    logging.info(f"Processing tile {tile_id} with bounds {bounds_str}")

    try:
        # Dictionary of downloaded layers
        download_dict = {}
        layers = {}

        download_dict = {
            f"{land_cover}_2020": f"s3://gfw2-data/climate/AFOLU_flux_model/LULUCF/outputs/IPCC_basic_classes/2020/40000_pixels/20240205/{tile_id}__IPCC_classes_2020.tif",
            planted_forest_type_layer: f"s3://gfw2-data/climate/carbon_model/other_emissions_inputs/plantation_type/SDPTv2/20230911/{tile_id}_plantation_type_oilpalm_woodfiber_other.tif",
            planted_forest_tree_crop_layer: f"s3://gfw2-data/climate/carbon_model/other_emissions_inputs/plantation_simpleType__planted_forest_tree_crop/SDPTv2/20230911/{tile_id}.tif",
            "peat": f"s3://gfw2-data/climate/carbon_model/other_emissions_inputs/peatlands/processed/20230315/{tile_id}_peat_mask_processed.tif",
            "dadap": f"s3://gfw2-data/climate/AFOLU_flux_model/organic_soils/inputs/processed/dadap_density/30m/dadap_{tile_id}.tif",
            "engert": f"s3://gfw2-data/climate/AFOLU_flux_model/organic_soils/inputs/processed/engert_density/30m/engert_{tile_id}.tif",
            "grip": f"s3://gfw2-data/climate/AFOLU_flux_model/organic_soils/inputs/processed/grip_density/30m/grip_density_{tile_id}.tif",
            "osm_roads": f"s3://gfw2-data/climate/AFOLU_flux_model/organic_soils/inputs/processed/osm_canals_density/30m/canals_density_{tile_id}.tif", # update once roads data is ready
            "osm_canals": f"s3://gfw2-data/climate/AFOLU_flux_model/organic_soils/inputs/processed/osm_canals_density/30m/canals_density_{tile_id}.tif",
            # descals oil palm layer
            # extraction mosaic dataset 
        }

        # Checks whether tile exists at all. Doesn't try to download chunk if the tile doesn't exist.
        tile_exists = check_for_tile(download_dict, is_final)

        if tile_exists == 0:
            logging.info(f"Tile {tile_id} does not exist. Skipping.")
            return

        logging.info(f"Tile {tile_id} exists. Proceeding with downloading data.")
        futures = prepare_to_download_chunk(bounds, download_dict, no_data_val)

        if not is_final:
            logging.info(f"Waiting for requests for data in chunk {bounds_str} in {tile_id}: {timestr()}")

        # Waits for requests to come back with data from S3
        for future in concurrent.futures.as_completed(futures):
            layer = futures[future]
            layers[layer] = future.result()
            logging.info(f"Downloaded data for layer: {layer}")

        data_in_chunk = check_chunk_for_data(layers, f"{land_cover}_", bounds_str, tile_id, no_data_val, is_final)

        if data_in_chunk == 0:
            logging.info(f"No data in chunk {bounds_str}. Skipping.")
            return

        logging.info(f"Data present in chunk {bounds_str}. Proceeding with processing.")

        # Initializes empty dictionaries for each type
        uint8_dict_layers = {}
        int16_dict_layers = {}
        float32_dict_layers = {}

        for key, array in layers.items():
            logging.info(f"Processing layer {key} with dtype {array.dtype}")
            if array.dtype == np.uint8:
                uint8_dict_layers[key] = array
            elif array.dtype == np.int16:
                int16_dict_layers[key] = array
            elif array.dtype == np.float32:
                float32_dict_layers[key] = array
            else:
                raise TypeError(f"{key} dtype not in list")

        peat_block = uint8_dict_layers["peat"]
        land_cover_block = uint8_dict_layers[f"{land_cover}_2020"]
        planted_forest_type_block = uint8_dict_layers[planted_forest_type_layer]
        # planted_forest_tree_crop_block = uint8_dict_layers[planted_forest_tree_crop_layer]
        dadap_block = float32_dict_layers["dadap"]
        osm_roads_block = float32_dict_layers["osm_roads"]
        osm_canals_block = float32_dict_layers["osm_canals"]
        engert_block = float32_dict_layers["engert"]
        grip_block = float32_dict_layers["grip"]

        logging.info(f"Creating drainage map in {bounds_str} in {tile_id}: {timestr()}")
        soil_block, state_out = process_soil(
            peat_block, land_cover_block, planted_forest_type_block, dadap_block, osm_roads_block, osm_canals_block, engert_block, grip_block
        )

        out_dict_uint32 = {
            "soil": soil_block,
            "state": state_out
        }

        out_dict_all_dtypes = {}

        for key, value in out_dict_uint32.items():
            data_type = value.dtype.name
            out_pattern = key
            year = 2020  # Hardcoded example year, change as needed
            out_dict_all_dtypes[key] = [value, data_type, out_pattern, f'{year}']

        logging.info(f"Saving and uploading rasters for chunk {bounds_str}.")
        save_and_upload_small_raster_set(bounds, chunk_length_pixels, tile_id, bounds_str, out_dict_all_dtypes, is_final)

        del out_dict_all_dtypes

        logging.info(f"Completed processing for chunk {bounds_str}.")

    except Exception as e:
        logging.error(f"Failed processing for {bounds_str}: {str(e)}")

# %%
@jit(nopython=True)
def accrete_node(combo, new):
    combo = combo*10 + new
    return combo

# %%
@jit(nopython=True)
def process_soil(peat_block, land_cover_block, planted_forest_type_block, dadap_block, osm_roads_block, osm_canals_block, engert_block, grip_block):
    rows, cols = peat_block.shape

    soil_block = np.empty((rows, cols), dtype=np.uint32)
    state_out = np.empty((rows, cols), dtype=np.uint32)

    for row in range(rows):
        for col in range(cols):
            peat = peat_block[row, col]
            land_cover = land_cover_block[row, col]
            planted_forest_type = planted_forest_type_block[row, col]
            dadap = dadap_block[row, col]
            osm_roads = osm_roads_block[row, col]
            osm_canals = osm_canals_block[row, col]
            engert = engert_block[row, col]
            grip = grip_block[row, col]

            node = 0
            
            if peat == 1:
                node = accrete_node(node, 1)
                if (dadap != 255 and dadap > 0) or (osm_canals != 255 and osm_canals > 0): 
                    node = accrete_node(node, 1)
                    soil_block[row, col] = 1  # 'drained'
                    state_out[row, col] = node  # 'drained'
                elif (engert != 255 and engert > 0) or (grip != 255 and grip > 0) or (osm_roads != 255 and osm_roads > 0):
                    node = accrete_node(node, 2)
                    soil_block[row, col] = 1  # 'drained'
                    state_out[row, col] = node  # 'drained'
                elif land_cover == 2 or land_cover == 3:  # 2 = cropland; 3 = settlement
                    node = accrete_node(node, 3)
                    soil_block[row, col] = 1  # 'drained'
                    state_out[row, col] = node  # 'drained'
                elif planted_forest_type != 255 and planted_forest_type > 0:  # note that we made need to remap planted forest type for emissions
                    node = accrete_node(node, 4)
                    soil_block[row, col] = 1  # 'drained'
                    state_out[row, col] = node  # 'drained'
                else:
                    node = accrete_node(node, 5)
                    soil_block[row, col] = 0  # 'undrained'
                    state_out[row, col] = node  # 'undrained'
            else:
                soil_block[row, col] = 0  # 'undrained'
                node = accrete_node(node, 2)
                state_out[row, col] = node  # 'undrained'

    return soil_block, state_out

# %%
# %%time

## Create LULUCF flux and carbon stock 2x2 deg rasters 

## Area to analyze
## chunk_params arguments: W, S, E, N, chunk size (degrees)
# chunk_params = [-180, -60, 180, 80, 2]  # entire world
# chunk_params = [-10, 40, 20, 70, 1]    # 30x30 deg (70N_010W), 900 chunks

# chunk_params = [-10, 60, 0, 70, 1]    # 10x10 deg (70N_010W), 100 chunks
# chunk_params = [-10, 65, -5, 70, 1]    # 5x5 deg (70N_010W), 25 chunks
# chunk_params = [-10, 68, -8, 70, 1]    # 2x2 deg (70N_010W), 4 chunks
# chunk_params = [-10, 69, -9, 70, 1]    # 1x1 deg (70N_010W), 1 chunk

# chunk_params = [10, 40, 20, 50, 2]    # 10x10 deg (50N_010E), 25 chunks
# chunk_params = [10, 40, 20, 50, 10]    # 10x10 deg (50N_010E), 1 chunk
# chunk_params = [10, 46, 14, 50, 2]   # 4x4 deg, 4 chunks
# chunk_params = [110, -10, 114, -6, 2]   # 4x4 deg, 4 chunks
# chunk_params = [10, 48, 12, 50, 1]   # 2x2 deg, 4 chunks
# chunk_params = [10, 49, 11, 50, 1]   # 1x1 deg, 1 chunk
# chunk_params = [10, 49, 11, 50, 0.5] # 1x1 deg, 4 chunks
# chunk_params = [10, 49.5, 10.5, 50, 0.25] # 0.5x0.5 deg, 4 chunks
# chunk_params = [10, 42, 11, 43, 0.5] # 1x1 deg, 4 chunks (some GLCLU code=254 for ocean and some land, so data should be output)
# chunk_params = [10, 49.75, 10.25, 50, 0.25] # 0.25x0.25 deg, 1 chunk (has data, no fire)
#chunk_params = [15, 41.75, 15.25, 42, 0.25] # 0.25x0.25 deg, 1 chunk (has data with fire)

# # Range of no-data cases for testing
# chunk_params = [20, 69.75, 20.25, 70, 0.25] # 0.25x0.25 deg, 1 chunk (tile exists for GLCLU but not all other inputs, e.g., fire)
# chunk_params = [110, -10, 120, 0, 2]    # 10x10 deg (00N_110E), 25 chunks (all chunks have land and should be output)
# chunk_params = [110, -20, 120, -10, 2]    # 10x10 deg (00N_110E), 25 chunks (all chunks have land and should be output)
# chunk_params = [0, 79.75, 0.25, 80, 0.25] # 0.25x0.25 deg, 1 chunk (no 80N_000E tile-- no data)
# chunk_params = [112, -12, 116, -8, 2]   # 2x2 deg, 1 chunk (bottom of Java, has data but mostly ocean)
# chunk_params = [10.875, 41.75, 11, 42, 0.25] # 0.25x0.25 deg, 1 chunk (entirely GLCLU code=255 for ocean, so no actual data-- nothing should be be output)
# chunk_params = [-10, 21.75, -9.75, 22, 0.25] # 0.25x0.25 deg, 1 chunk (has data but entirely desert (fully GLCLU code=0))
# chunk_params = [10, 49.75, 10.25, 50, 0.25] # 0.25x0.25 deg, 1 chunk (has data)

#drainage chunks for testing
# chunk_params = [112.75, -2.75, 113.0, -2.5, 0.25] # 1 chunk, 0.25 degrees has data. Southern Borneo
# chunk_params = [110.0, -10.0, 120.0, 0.0, 2] # tile 00N_110E, Indonesia, 25 2-degree chunks
# chunk_params = [10.0, 0.0, 20.0, 10.0, 2] # tile 10N_010E, Central Africa, 25 2-degree chunks
# chunk_params = [16.0, 2.0, 18.0, 4.0, 2] #tile 10N_010E, Central Africa, 1 2-degree chunk with data
# chunk_params = [114.0, -4.0, 116.0, -2.0, 2] # tile 00N_110E, Souther Borneo, 1 2-degree chunk with data
# chunk_params = [-76.0, -2.0, -74.0, 0.0, 2] #tile 00N_080W, Peru, 1 2-degree chunk with data
chunk_params = [-180, -60, 180, 80, 2]  # entire world

# Makes list of chunks to analyze
chunks = get_chunk_bounds(chunk_params)  
print("Processing", len(chunks), "chunks")
# print(chunks)

# Determines if the output file names for final versions of outputs should be used
is_final = False
if len(chunks) > 90:
    is_final = True
    print("Running as final model.")

# Creates list of tasks to run (1 task = 1 chunk for all years)
delayed_result = [dask.delayed(calculate_and_upload_drainage)(chunk, is_final) for chunk in chunks]

# Actually runs analysis
results = dask.compute(*delayed_result)
results
# Out:
# Processing 12600 chunks
# Running as final model.
# Requesting data in chunk -68_56_-66_58 in 60N_070W: 20240607_17_16_15
# Requesting data in chunk 122_22_124_24 in 30N_120E: 20240607_17_16_15
# Requesting data in chunk 12_-4_14_-2 in 00N_010E: 20240607_17_16_15
# Requesting data in chunk 128_-18_130_-16 in 10S_120E: 20240607_17_16_15
# Requesting data in chunk -92_32_-90_34 in 40N_100W: 20240607_17_16_15
# Requesting data in chunk 54_66_56_68 in 70N_050E: 20240607_17_16_15
# Requesting data in chunk -16_18_-14_20 in 20N_020W: 20240607_17_16_15
# Requesting data in chunk 102_28_104_30 in 30N_100E: 20240607_17_16_15
# Requesting data in chunk 14_-40_16_-38 in 30S_010E: 20240607_17_16_15
# Requesting data in chunk -96_42_-94_44 in 50N_100W: 20240607_17_16_15
# Requesting data in chunk 130_2_132_4 in 10N_130E: 20240607_17_16_15
# Requesting data in chunk -102_54_-100_56 in 60N_110W: 20240607_17_16_15
# Requesting data in chunk 22_26_24_28 in 30N_020E: 20240607_17_16_15
# Requesting data in chunk -60_16_-58_18 in 20N_060W: 20240607_17_16_15
# Requesting data in chunk -106_-26_-104_-24 in 20S_110W: 20240607_17_16_15
# Requesting data in chunk -112_56_-110_58 in 60N_120W: 20240607_17_16_15
# Requesting data in chunk 22_24_24_26 in 30N_020E: 20240607_17_16_15
# Requesting data in chunk 12_-22_14_-20 in 20S_010E: 20240607_17_16_15
# Requesting data in chunk 128_44_130_46 in 50N_120E: 20240607_17_16_15
# Requesting data in chunk -64_50_-62_52 in 60N_070W: 20240607_17_16_15
# Requesting data in chunk 140_50_142_52 in 60N_140E: 20240607_17_16_15
# Requesting data in chunk 22_-38_24_-36 in 30S_020E: 20240607_17_16_15
# Requesting data in chunk -124_42_-122_44 in 50N_130W: 20240607_17_16_15
# Requesting data in chunk -52_-36_-50_-34 in 30S_060W: 20240607_17_16_15
# Requesting data in chunk -54_8_-52_10 in 10N_060W: 20240607_17_16_15
# Requesting data in chunk -6_14_-4_16 in 20N_010W: 20240607_17_16_15
# Requesting data in chunk -102_56_-100_58 in 60N_110W: 20240607_17_16_15
# Requesting data in chunk 82_72_84_74 in 80N_080E: 20240607_17_16_15
# Requesting data in chunk 26_64_28_66 in 70N_020E: 20240607_17_16_15
# Requesting data in chunk -142_58_-140_60 in 60N_150W: 20240607_17_16_15
# Requesting data in chunk -92_30_-90_32 in 40N_100W: 20240607_17_16_15
# Requesting data in chunk -46_4_-44_6 in 10N_050W: 20240607_17_16_15
# Requesting data in chunk 156_-2_158_0 in 00N_150E: 20240607_17_16_15
# Requesting data in chunk -120_68_-118_70 in 70N_120W: 20240607_17_16_15
# Requesting data in chunk 88_28_90_30 in 30N_080E: 20240607_17_16_15
# Requesting data in chunk -80_36_-78_38 in 40N_080W: 20240607_17_16_15
# Requesting data in chunk 128_14_130_16 in 20N_120E: 20240607_17_16_15
# Requesting data in chunk 140_36_142_38 in 40N_140E: 20240607_17_16_15
# Requesting data in chunk -138_56_-136_58 in 60N_140W: 20240607_17_16_15
# Requesting data in chunk 106_42_108_44 in 50N_100E: 20240607_17_16_15
# Requesting data in chunk 116_30_118_32 in 40N_110E: 20240607_17_16_15
# Requesting data in chunk 48_-16_50_-14 in 10S_040E: 20240607_17_16_15
# Requesting data in chunk 84_48_86_50 in 50N_080E: 20240607_17_16_15
# Requesting data in chunk -100_54_-98_56 in 60N_100W: 20240607_17_16_15
# Requesting data in chunk -66_-4_-64_-2 in 00N_070W: 20240607_17_16_15
# Requesting data in chunk 102_-2_104_0 in 00N_100E: 20240607_17_16_15
# Requesting data in chunk -74_24_-72_26 in 30N_080W: 20240607_17_16_15
# Requesting data in chunk 50_70_52_72 in 80N_050E: 20240607_17_16_15
# Requesting data in chunk -90_78_-88_80 in 80N_090W: 20240607_17_16_15
# Requesting data in chunk 144_48_146_50 in 50N_140E: 20240607_17_16_15
# Requesting data in chunk 128_52_130_54 in 60N_120E: 20240607_17_16_15
# Requesting data in chunk -82_34_-80_36 in 40N_090W: 20240607_17_16_15
# Requesting data in chunk -68_44_-66_46 in 50N_070W: 20240607_17_16_15
# Requesting data in chunk 116_-32_118_-30 in 30S_110E: 20240607_17_16_15
# Requesting data in chunk -56_-60_-54_-58 in 50S_060W: 20240607_17_16_15
# Requesting data in chunk 106_0_108_2 in 10N_100E: 20240607_17_16_15
# Requesting data in chunk -78_-38_-76_-36 in 30S_080W: 20240607_17_16_15
# Requesting data in chunk 94_70_96_72 in 80N_090E: 20240607_17_16_15
# Requesting data in chunk -88_50_-86_52 in 60N_090W: 20240607_17_16_15
# Requesting data in chunk 126_70_128_72 in 80N_120E: 20240607_17_16_15
# Requesting data in chunk 102_12_104_14 in 20N_100E: 20240607_17_16_15
# Requesting data in chunk -106_26_-104_28 in 30N_110W: 20240607_17_16_16
# Requesting data in chunk -126_56_-124_58 in 60N_130W: 20240607_17_16_15
# Requesting data in chunk 82_28_84_30 in 30N_080E: 20240607_17_16_16
# Requesting data in chunk 94_4_96_6 in 10N_090E: 20240607_17_16_15
# Requesting data in chunk -82_48_-80_50 in 50N_090W: 20240607_17_16_15
# Requesting data in chunk 124_-8_126_-6 in 00N_120E: 20240607_17_16_15
# Requesting data in chunk -74_22_-72_24 in 30N_080W: 20240607_17_16_15
# Requesting data in chunk 164_-2_166_0 in 00N_160E: 20240607_17_16_15
# Requesting data in chunk 56_0_58_2 in 10N_050E: 20240607_17_16_15
# Requesting data in chunk -156_50_-154_52 in 60N_160W: 20240607_17_16_15
# Requesting data in chunk -108_20_-106_22 in 30N_110W: 20240607_17_16_15
# Requesting data in chunk -60_-22_-58_-20 in 20S_060W: 20240607_17_16_15
# Requesting data in chunk -10_62_-8_64 in 70N_010W: 20240607_17_16_15
# Requesting data in chunk 2_-6_4_-4 in 00N_000E: 20240607_17_16_15
# Requesting data in chunk 60_46_62_48 in 50N_060E: 20240607_17_16_16
# Requesting data in chunk 118_-18_120_-16 in 10S_110E: 20240607_17_16_16
# Requesting data in chunk 58_68_60_70 in 70N_050E: 20240607_17_16_16
# Requesting data in chunk -174_-20_-172_-18 in 10S_180W: 20240607_17_16_16
# Requesting data in chunk -80_-12_-78_-10 in 10S_080W: 20240607_17_16_16
# Requesting data in chunk -72_2_-70_4 in 10N_080W: 20240607_17_16_16
# Requesting data in chunk 4_-2_6_0 in 00N_000E: 20240607_17_16_16
# Requesting data in chunk -66_44_-64_46 in 50N_070W: 20240607_17_16_15
# Requesting data in chunk -62_12_-60_14 in 20N_070W: 20240607_17_16_15
# Requesting data in chunk 62_22_64_24 in 30N_060E: 20240607_17_16_15
# Requesting data in chunk -42_-12_-40_-10 in 10S_050W: 20240607_17_16_15
# Requesting data in chunk 116_20_118_22 in 30N_110E: 20240607_17_16_15
# Requesting data in chunk 78_50_80_52 in 60N_070E: 20240607_17_16_15
# Requesting data in chunk 12_72_14_74 in 80N_010E: 20240607_17_16_15
# Requesting data in chunk 26_76_28_78 in 80N_020E: 20240607_17_16_15
# Requesting data in chunk -98_8_-96_10 in 10N_100W: 20240607_17_16_15
# Requesting data in chunk 96_66_98_68 in 70N_090E: 20240607_17_16_15
# Requesting data in chunk -156_56_-154_58 in 60N_160W: 20240607_17_16_15
# Requesting data in chunk 42_34_44_36 in 40N_040E: 20240607_17_16_15
# Requesting data in chunk -124_68_-122_70 in 70N_130W: 20240607_17_16_16
# Requesting data in chunk 0_14_2_16 in 20N_000E: 20240607_17_16_16
# Requesting data in chunk 6_16_8_18 in 20N_000E: 20240607_17_16_16
# Requesting data in chunk -74_-40_-72_-38 in 30S_080W: 20240607_17_16_16
# Requesting data in chunk 12_-14_14_-12 in 10S_010E: 20240607_17_16_16
# Requesting data in chunk -104_16_-102_18 in 20N_110W: 20240607_17_16_16
# Requesting data in chunk 122_68_124_70 in 70N_120E: 20240607_17_16_16
# Requesting data in chunk 114_72_116_74 in 80N_110E: 20240607_17_16_16
# Requesting data in chunk 64_38_66_40 in 40N_060E: 20240607_17_16_16
# Requesting data in chunk 86_52_88_54 in 60N_080E: 20240607_17_16_15
# Requesting data in chunk -8_26_-6_28 in 30N_010W: 20240607_17_16_15
# Requesting data in chunk -14_60_-12_62 in 70N_020W: 20240607_17_16_15
# Requesting data in chunk 172_58_174_60 in 60N_170E: 20240607_17_16_15
# Requesting data in chunk 68_62_70_64 in 70N_060E: 20240607_17_16_15
# Requesting data in chunk -76_-32_-74_-30 in 30S_080W: 20240607_17_16_16
# Requesting data in chunk 6_56_8_58 in 60N_000E: 20240607_17_16_16
# Requesting data in chunk 122_60_124_62 in 70N_120E: 20240607_17_16_16
# Requesting data in chunk -90_72_-88_74 in 80N_090W: 20240607_17_16_16
# Requesting data in chunk 120_52_122_54 in 60N_120E: 20240607_17_16_16
# Requesting data in chunk 94_6_96_8 in 10N_090E: 20240607_17_16_16
# Requesting data in chunk 76_26_78_28 in 30N_070E: 20240607_17_16_16
# Requesting data in chunk 110_76_112_78 in 80N_110E: 20240607_17_16_16
# Requesting data in chunk 64_70_66_72 in 80N_060E: 20240607_17_16_16
# Requesting data in chunk 16_10_18_12 in 20N_010E: 20240607_17_16_16
# Requesting data in chunk -128_62_-126_64 in 70N_130W: 20240607_17_16_16
# Requesting data in chunk -52_2_-50_4 in 10N_060W: 20240607_17_16_16
# Requesting data in chunk 116_-4_118_-2 in 00N_110E: 20240607_17_16_16
# Requesting data in chunk -42_-26_-40_-24 in 20S_050W: 20240607_17_16_15
# Requesting data in chunk 120_-16_122_-14 in 10S_120E: 20240607_17_16_15
# Requesting data in chunk 122_66_124_68 in 70N_120E: 20240607_17_16_15
# Requesting data in chunk -68_-12_-66_-10 in 10S_070W: 20240607_17_16_15
# Requesting data in chunk 156_-16_158_-14 in 10S_150E: 20240607_17_16_16
# Requesting data in chunk -178_-12_-176_-10 in 10S_180W: 20240607_17_16_16
# Requesting data in chunk -72_56_-70_58 in 60N_080W: 20240607_17_16_15
# Requesting data in chunk -16_38_-14_40 in 40N_020W: 20240607_17_16_15
# Requesting data in chunk 154_54_156_56 in 60N_150E: 20240607_17_16_15
# Requesting data in chunk 8_20_10_22 in 30N_000E: 20240607_17_16_16
# Requesting data in chunk 66_54_68_56 in 60N_060E: 20240607_17_16_16
# Requesting data in chunk -16_30_-14_32 in 40N_020W: 20240607_17_16_16
# Requesting data in chunk 10_24_12_26 in 30N_010E: 20240607_17_16_16
# Requesting data in chunk 12_76_14_78 in 80N_010E: 20240607_17_16_16
# Requesting data in chunk 118_-22_120_-20 in 20S_110E: 20240607_17_16_16
# Requesting data in chunk 130_66_132_68 in 70N_130E: 20240607_17_16_16
# Requesting data in chunk 96_28_98_30 in 30N_090E: 20240607_17_16_16
# Requesting data in chunk 108_36_110_38 in 40N_100E: 20240607_17_16_16
# Requesting data in chunk 18_50_20_52 in 60N_010E: 20240607_17_16_16
# Requesting data in chunk -48_-24_-46_-22 in 20S_050W: 20240607_17_16_16
# Requesting data in chunk 14_50_16_52 in 60N_010E: 20240607_17_16_16
# Requesting data in chunk 166_52_168_54 in 60N_160E: 20240607_17_16_16
# Requesting data in chunk -74_70_-72_72 in 80N_080W: 20240607_17_16_16
# Requesting data in chunk 88_78_90_80 in 80N_080E: 20240607_17_16_15
# Requesting data in chunk -98_34_-96_36 in 40N_100W: 20240607_17_16_15
# Requesting data in chunk 96_-6_98_-4 in 00N_090E: 20240607_17_16_15
# Requesting data in chunk 160_56_162_58 in 60N_160E: 20240607_17_16_15
# Requesting data in chunk -110_10_-108_12 in 20N_110W: 20240607_17_16_15
# Requesting data in chunk 32_-16_34_-14 in 10S_030E: 20240607_17_16_15
# Requesting data in chunk 136_-24_138_-22 in 20S_130E: 20240607_17_16_15
# Requesting data in chunk 138_30_140_32 in 40N_130E: 20240607_17_16_15
# Requesting data in chunk 102_62_104_64 in 70N_100E: 20240607_17_16_16
# Requesting data in chunk -70_72_-68_74 in 80N_070W: 20240607_17_16_16
# Requesting data in chunk 36_-28_38_-26 in 20S_030E: 20240607_17_16_16
# Requesting data in chunk -122_42_-120_44 in 50N_130W: 20240607_17_16_16
# Requesting data in chunk -116_64_-114_66 in 70N_120W: 20240607_17_16_16
# Requesting data in chunk -66_76_-64_78 in 80N_070W: 20240607_17_16_16
# Requesting data in chunk -6_10_-4_12 in 20N_010W: 20240607_17_16_16
# Requesting data in chunk -4_12_-2_14 in 20N_010W: 20240607_17_16_16
# Requesting data in chunk -66_18_-64_20 in 20N_070W: 20240607_17_16_16
# Requesting data in chunk -76_14_-74_16 in 20N_080W: 20240607_17_16_16
# Requesting data in chunk 18_6_20_8 in 10N_010E: 20240607_17_16_16
# Requesting data in chunk -6_56_-4_58 in 60N_010W: 20240607_17_16_16
# Requesting data in chunk -74_0_-72_2 in 10N_080W: 20240607_17_16_16
# Requesting data in chunk 18_56_20_58 in 60N_010E: 20240607_17_16_15
# Requesting data in chunk 0_48_2_50 in 50N_000E: 20240607_17_16_16
# Requesting data in chunk -16_6_-14_8 in 10N_020W: 20240607_17_16_16
# Requesting data in chunk -12_68_-10_70 in 70N_020W: 20240607_17_16_16
# Requesting data in chunk 132_56_134_58 in 60N_130E: 20240607_17_16_16
# Requesting data in chunk 82_38_84_40 in 40N_080E: 20240607_17_16_16
# Requesting data in chunk 112_-16_114_-14 in 10S_110E: 20240607_17_16_16
# Requesting data in chunk 82_10_84_12 in 20N_080E: 20240607_17_16_16
# Requesting data in chunk -4_24_-2_26 in 30N_010W: 20240607_17_16_16
# Requesting data in chunk -2_66_0_68 in 70N_010W: 20240607_17_16_16
# Requesting data in chunk 112_-28_114_-26 in 20S_110E: 20240607_17_16_15
# Requesting data in chunk -170_70_-168_72 in 80N_170W: 20240607_17_16_15
# Requesting data in chunk 148_-26_150_-24 in 20S_140E: 20240607_17_16_15
# Requesting data in chunk -94_4_-92_6 in 10N_100W: 20240607_17_16_15
# Requesting data in chunk 176_56_178_58 in 60N_170E: 20240607_17_16_15
# Requesting data in chunk 16_-18_18_-16 in 10S_010E: 20240607_17_16_15
# Requesting data in chunk -30_62_-28_64 in 70N_030W: 20240607_17_16_15
# Requesting data in chunk 10_18_12_20 in 20N_010E: 20240607_17_16_16
# Requesting data in chunk -80_-30_-78_-28 in 20S_080W: 20240607_17_16_16
# Requesting data in chunk 84_4_86_6 in 10N_080E: 20240607_17_16_16
# Requesting data in chunk -94_30_-92_32 in 40N_100W: 20240607_17_16_16
# Requesting data in chunk -82_36_-80_38 in 40N_090W: 20240607_17_16_16
# Requesting data in chunk 178_-42_180_-40 in 40S_170E: 20240607_17_16_16
# Requesting data in chunk 14_14_16_16 in 20N_010E: 20240607_17_16_16
# Requesting data in chunk 14_-16_16_-14 in 10S_010E: 20240607_17_16_16
# Requesting data in chunk 14_32_16_34 in 40N_010E: 20240607_17_16_16
# Requesting data in chunk -102_52_-100_54 in 60N_110W: 20240607_17_16_16
# Requesting data in chunk -122_76_-120_78 in 80N_130W: 20240607_17_16_16
# Requesting data in chunk 54_-16_56_-14 in 10S_050E: 20240607_17_16_16
# Requesting data in chunk 148_54_150_56 in 60N_140E: 20240607_17_16_16
# Requesting data in chunk 100_8_102_10 in 10N_100E: 20240607_17_16_16
# Requesting data in chunk 132_32_134_34 in 40N_130E: 20240607_17_16_16
# Requesting data in chunk 12_10_14_12 in 20N_010E: 20240607_17_16_16
# Requesting data in chunk 44_42_46_44 in 50N_040E: 20240607_17_16_16
# Requesting data in chunk 56_44_58_46 in 50N_050E: 20240607_17_16_16
# Requesting data in chunk 110_-20_112_-18 in 10S_110E: 20240607_17_16_16
# Requesting data in chunk -2_52_0_54 in 60N_010W: 20240607_17_16_16
# Requesting data in chunk -122_52_-120_54 in 60N_130W: 20240607_17_16_16
# Requesting data in chunk -90_36_-88_38 in 40N_090W: 20240607_17_16_16
# Requesting data in chunk -76_26_-74_28 in 30N_080W: 20240607_17_16_16
# Requesting data in chunk 128_46_130_48 in 50N_120E: 20240607_17_16_16
# Requesting data in chunk 38_-34_40_-32 in 30S_030E: 20240607_17_16_16
# Requesting data in chunk 144_0_146_2 in 10N_140E: 20240607_17_16_16
# Requesting data in chunk 46_12_48_14 in 20N_040E: 20240607_17_16_16
# Requesting data in chunk 48_34_50_36 in 40N_040E: 20240607_17_16_16
# Requesting data in chunk -96_74_-94_76 in 80N_100W: 20240607_17_16_16
# Requesting data in chunk -126_40_-124_42 in 50N_130W: 20240607_17_16_16
# Requesting data in chunk -56_-8_-54_-6 in 00N_060W: 20240607_17_16_16
# Requesting data in chunk 98_6_100_8 in 10N_090E: 20240607_17_16_16
# Requesting data in chunk -158_50_-156_52 in 60N_160W: 20240607_17_16_16
# Requesting data in chunk -66_-22_-64_-20 in 20S_070W: 20240607_17_16_16
# Requesting data in chunk 10_22_12_24 in 30N_010E: 20240607_17_16_16
# Requesting data in chunk -100_38_-98_40 in 40N_100W: 20240607_17_16_16
# Requesting data in chunk 156_50_158_52 in 60N_150E: 20240607_17_16_16
# Requesting data in chunk -176_54_-174_56 in 60N_180W: 20240607_17_16_16
# Requesting data in chunk -72_12_-70_14 in 20N_080W: 20240607_17_16_16
# Requesting data in chunk -72_-30_-70_-28 in 20S_080W: 20240607_17_16_16
# Requesting data in chunk -144_72_-142_74 in 80N_150W: 20240607_17_16_16
# Requesting data in chunk 78_30_80_32 in 40N_070E: 20240607_17_16_16
# Requesting data in chunk 174_-32_176_-30 in 30S_170E: 20240607_17_16_16
# Requesting data in chunk -156_52_-154_54 in 60N_160W: 20240607_17_16_16
# Requesting data in chunk -178_-16_-176_-14 in 10S_180W: 20240607_17_16_16
# Requesting data in chunk 100_2_102_4 in 10N_100E: 20240607_17_16_16
# Requesting data in chunk -82_6_-80_8 in 10N_090W: 20240607_17_16_16
# Requesting data in chunk -42_-24_-40_-22 in 20S_050W: 20240607_17_16_15
# Requesting data in chunk 150_-10_152_-8 in 00N_150E: 20240607_17_16_15
# Requesting data in chunk -72_-22_-70_-20 in 20S_080W: 20240607_17_16_15
# Requesting data in chunk -118_72_-116_74 in 80N_120W: 20240607_17_16_15
# Requesting data in chunk 8_44_10_46 in 50N_000E: 20240607_17_16_15
# Requesting data in chunk -78_14_-76_16 in 20N_080W: 20240607_17_16_15
# Requesting data in chunk 22_-16_24_-14 in 10S_020E: 20240607_17_16_15
# Requesting data in chunk -60_40_-58_42 in 50N_060W: 20240607_17_16_15
# Requesting data in chunk -72_20_-70_22 in 30N_080W: 20240607_17_16_15
# Requesting data in chunk -90_52_-88_54 in 60N_090W: 20240607_17_16_15
# Requesting data in chunk 56_-22_58_-20 in 20S_050E: 20240607_17_16_15
# Requesting data in chunk 12_-38_14_-36 in 30S_010E: 20240607_17_16_15
# Requesting data in chunk 54_-18_56_-16 in 10S_050E: 20240607_17_16_16
# Requesting data in chunk -88_70_-86_72 in 80N_090W: 20240607_17_16_16
# Requesting data in chunk 46_40_48_42 in 50N_040E: 20240607_17_16_16
# Requesting data in chunk 102_16_104_18 in 20N_100E: 20240607_17_16_16
# Requesting data in chunk -10_22_-8_24 in 30N_010W: 20240607_17_16_16
# Requesting data in chunk -118_78_-116_80 in 80N_120W: 20240607_17_16_16
# Requesting data in chunk 8_22_10_24 in 30N_000E: 20240607_17_16_17
# Requesting data in chunk 42_0_44_2 in 10N_040E: 20240607_17_16_17
# Requesting data in chunk -122_46_-120_48 in 50N_130W: 20240607_17_16_16
# Requesting data in chunk -132_70_-130_72 in 80N_140W: 20240607_17_16_16
# Requesting data in chunk 160_-26_162_-24 in 20S_160E: 20240607_17_16_16
# Requesting data in chunk -138_78_-136_80 in 80N_140W: 20240607_17_16_16
# Requesting data in chunk 36_28_38_30 in 30N_030E: 20240607_17_16_16
# Requesting data in chunk -96_40_-94_42 in 50N_100W: 20240607_17_16_16
# Requesting data in chunk 130_42_132_44 in 50N_130E: 20240607_17_16_16
# Requesting data in chunk -32_-8_-30_-6 in 00N_040W: 20240607_17_16_16
# Requesting data in chunk 128_58_130_60 in 60N_120E: 20240607_17_16_16
# Requesting data in chunk -38_-20_-36_-18 in 10S_040W: 20240607_17_16_16
# Requesting data in chunk 108_76_110_78 in 80N_100E: 20240607_17_16_16
# Requesting data in chunk 8_10_10_12 in 20N_000E: 20240607_17_16_16
# Requesting data in chunk -76_-54_-74_-52 in 50S_080W: 20240607_17_16_17
# Requesting data in chunk 96_72_98_74 in 80N_090E: 20240607_17_16_17
# Requesting data in chunk 158_66_160_68 in 70N_150E: 20240607_17_16_17
# Requesting data in chunk -88_32_-86_34 in 40N_090W: 20240607_17_16_17
# Requesting data in chunk 152_-26_154_-24 in 20S_150E: 20240607_17_16_17
# Requesting data in chunk 142_-40_144_-38 in 30S_140E: 20240607_17_16_17
# Requesting data in chunk 102_24_104_26 in 30N_100E: 20240607_17_16_17
# Requesting data in chunk -120_32_-118_34 in 40N_120W: 20240607_17_16_17
# Requesting data in chunk -74_-48_-72_-46 in 40S_080W: 20240607_17_16_17
# Requesting data in chunk 60_56_62_58 in 60N_060E: 20240607_17_16_16
# Requesting data in chunk 26_-10_28_-8 in 00N_020E: 20240607_17_16_17
# Requesting data in chunk 20_58_22_60 in 60N_020E: 20240607_17_16_17
# Requesting data in chunk -94_76_-92_78 in 80N_100W: 20240607_17_16_17
# Requesting data in chunk 46_56_48_58 in 60N_040E: 20240607_17_16_16
# Requesting data in chunk -108_30_-106_32 in 40N_110W: 20240607_17_16_16
# Requesting data in chunk 132_-10_134_-8 in 00N_130E: 20240607_17_16_16
# Requesting data in chunk -136_74_-134_76 in 80N_140W: 20240607_17_16_16
# Requesting data in chunk -138_66_-136_68 in 70N_140W: 20240607_17_16_16
# Requesting data in chunk -116_74_-114_76 in 80N_120W: 20240607_17_16_16
# Requesting data in chunk 80_14_82_16 in 20N_080E: 20240607_17_16_16
# Requesting data in chunk 122_12_124_14 in 20N_120E: 20240607_17_16_17
# Requesting data in chunk -150_54_-148_56 in 60N_150W: 20240607_17_16_17
# Requesting data in chunk -68_54_-66_56 in 60N_070W: 20240607_17_16_17
# Requesting data in chunk 24_32_26_34 in 40N_020E: 20240607_17_16_17
# Requesting data in chunk -116_18_-114_20 in 20N_120W: 20240607_17_16_17
# Requesting data in chunk 94_38_96_40 in 40N_090E: 20240607_17_16_17
# Requesting data in chunk -158_52_-156_54 in 60N_160W: 20240607_17_16_17
# Requesting data in chunk 94_60_96_62 in 70N_090E: 20240607_17_16_16
# Requesting data in chunk 12_74_14_76 in 80N_010E: 20240607_17_16_16
# Requesting data in chunk 50_74_52_76 in 80N_050E: 20240607_17_16_17
# Requesting data in chunk -82_74_-80_76 in 80N_090W: 20240607_17_16_17
# Requesting data in chunk -70_-54_-68_-52 in 50S_070W: 20240607_17_16_17
# Requesting data in chunk -74_-46_-72_-44 in 40S_080W: 20240607_17_16_16
# Requesting data in chunk -56_-52_-54_-50 in 50S_060W: 20240607_17_16_17
# Requesting data in chunk 36_26_38_28 in 30N_030E: 20240607_17_16_16
# Requesting data in chunk 106_78_108_80 in 80N_100E: 20240607_17_16_16
# Requesting data in chunk -74_76_-72_78 in 80N_080W: 20240607_17_16_16
# Requesting data in chunk -80_-40_-78_-38 in 30S_080W: 20240607_17_16_16
# Requesting data in chunk 48_-18_50_-16 in 10S_040E: 20240607_17_16_16
# Requesting data in chunk -10_2_-8_4 in 10N_010W: 20240607_17_16_16
# Requesting data in chunk 44_22_46_24 in 30N_040E: 20240607_17_16_17
# Requesting data in chunk 34_-26_36_-24 in 20S_030E: 20240607_17_16_17
# Requesting data in chunk -82_14_-80_16 in 20N_090W: 20240607_17_16_17
# Requesting data in chunk -92_28_-90_30 in 30N_100W: 20240607_17_16_17
# Requesting data in chunk 58_52_60_54 in 60N_050E: 20240607_17_16_17
# Requesting data in chunk 4_28_6_30 in 30N_000E: 20240607_17_16_17
# Requesting data in chunk 88_20_90_22 in 30N_080E: 20240607_17_16_17
# Requesting data in chunk 32_52_34_54 in 60N_030E: 20240607_17_16_17
# Requesting data in chunk 0_56_2_58 in 60N_000E: 20240607_17_16_17
# Requesting data in chunk -56_16_-54_18 in 20N_060W: 20240607_17_16_17
# Requesting data in chunk -22_60_-20_62 in 70N_030W: 20240607_17_16_17
# Requesting data in chunk 106_58_108_60 in 60N_100E: 20240607_17_16_17
# Requesting data in chunk -120_12_-118_14 in 20N_120W: 20240607_17_16_17
# Requesting data in chunk 126_54_128_56 in 60N_120E: 20240607_17_16_17
# Requesting data in chunk -68_-56_-66_-54 in 50S_070W: 20240607_17_16_17
# Requesting data in chunk 94_76_96_78 in 80N_090E: 20240607_17_16_17
# Requesting data in chunk 150_-12_152_-10 in 10S_150E: 20240607_17_16_17
# Requesting data in chunk 134_-8_136_-6 in 00N_130E: 20240607_17_16_17
# Requesting data in chunk -80_6_-78_8 in 10N_080W: 20240607_17_16_17
# Requesting data in chunk -80_60_-78_62 in 70N_080W: 20240607_17_16_17
# Requesting data in chunk -74_56_-72_58 in 60N_080W: 20240607_17_16_17
# Requesting data in chunk 86_14_88_16 in 20N_080E: 20240607_17_16_17
# Requesting data in chunk -2_58_0_60 in 60N_010W: 20240607_17_16_17
# Requesting data in chunk 18_-12_20_-10 in 10S_010E: 20240607_17_16_17
# Requesting data in chunk 84_26_86_28 in 30N_080E: 20240607_17_16_17
# Requesting data in chunk -18_50_-16_52 in 60N_020W: 20240607_17_16_17
# Requesting data in chunk -158_54_-156_56 in 60N_160W: 20240607_17_16_17
# Requesting data in chunk 50_18_52_20 in 20N_050E: 20240607_17_16_17
# Requesting data in chunk -98_22_-96_24 in 30N_100W: 20240607_17_16_17
# Requesting data in chunk -90_16_-88_18 in 20N_090W: 20240607_17_16_17
# Requesting data in chunk -72_-10_-70_-8 in 00N_080W: 20240607_17_16_17
# Requesting data in chunk -56_58_-54_60 in 60N_060W: 20240607_17_16_17
# Requesting data in chunk -64_-20_-62_-18 in 10S_070W: 20240607_17_16_17
# Requesting data in chunk -2_22_0_24 in 30N_010W: 20240607_17_16_16
# Requesting data in chunk 92_-10_94_-8 in 00N_090E: 20240607_17_16_16
# Requesting data in chunk 54_14_56_16 in 20N_050E: 20240607_17_16_16
# Requesting data in chunk 116_16_118_18 in 20N_110E: 20240607_17_16_16
# Requesting data in chunk -52_-56_-50_-54 in 50S_060W: 20240607_17_16_16
# Requesting data in chunk 114_0_116_2 in 10N_110E: 20240607_17_16_17
# Requesting data in chunk 100_36_102_38 in 40N_100E: 20240607_17_16_17
# Requesting data in chunk -2_48_0_50 in 50N_010W: 20240607_17_16_17
# Requesting data in chunk 2_6_4_8 in 10N_000E: 20240607_17_16_17
# Requesting data in chunk -134_70_-132_72 in 80N_140W: 20240607_17_16_17
# Requesting data in chunk 66_26_68_28 in 30N_060E: 20240607_17_16_16
# Requesting data in chunk 172_62_174_64 in 70N_170E: 20240607_17_16_16
# Requesting data in chunk 44_32_46_34 in 40N_040E: 20240607_17_16_16
# Requesting data in chunk -144_62_-142_64 in 70N_150W: 20240607_17_16_16
# Requesting data in chunk -106_-24_-104_-22 in 20S_110W: 20240607_17_16_16
# Requesting data in chunk 102_78_104_80 in 80N_100E: 20240607_17_16_16
# Requesting data in chunk 80_46_82_48 in 50N_080E: 20240607_17_16_17
# Requesting data in chunk 148_56_150_58 in 60N_140E: 20240607_17_16_17
# Requesting data in chunk -82_-36_-80_-34 in 30S_090W: 20240607_17_16_16
# Requesting data in chunk 84_2_86_4 in 10N_080E: 20240607_17_16_17
# Requesting data in chunk -84_0_-82_2 in 10N_090W: 20240607_17_16_17
# Requesting data in chunk 132_-14_134_-12 in 10S_130E: 20240607_17_16_17
# Requesting data in chunk 168_52_170_54 in 60N_160E: 20240607_17_16_17
# Requesting data in chunk -76_-50_-74_-48 in 40S_080W: 20240607_17_16_17
# Requesting data in chunk 72_26_74_28 in 30N_070E: 20240607_17_16_17
# Requesting data in chunk 112_48_114_50 in 50N_110E: 20240607_17_16_17
# Requesting data in chunk -58_42_-56_44 in 50N_060W: 20240607_17_16_17
# Requesting data in chunk -78_-10_-76_-8 in 00N_080W: 20240607_17_16_17
# Requesting data in chunk 144_44_146_46 in 50N_140E: 20240607_17_16_17
# Requesting data in chunk 54_46_56_48 in 50N_050E: 20240607_17_16_17
# Requesting data in chunk -56_-28_-54_-26 in 20S_060W: 20240607_17_16_17
# Requesting data in chunk 146_-42_148_-40 in 40S_140E: 20240607_17_16_17
# Requesting data in chunk -48_-28_-46_-26 in 20S_050W: 20240607_17_16_17
# Requesting data in chunk 100_0_102_2 in 10N_100E: 20240607_17_16_17
# Requesting data in chunk 54_16_56_18 in 20N_050E: 20240607_17_16_17
# Requesting data in chunk -90_62_-88_64 in 70N_090W: 20240607_17_16_17
# Requesting data in chunk 144_72_146_74 in 80N_140E: 20240607_17_16_17
# Requesting data in chunk 178_-48_180_-46 in 40S_170E: 20240607_17_16_17
# Requesting data in chunk -70_-34_-68_-32 in 30S_070W: 20240607_17_16_16
# Requesting data in chunk -120_24_-118_26 in 30N_120W: 20240607_17_16_16
# Requesting data in chunk 50_22_52_24 in 30N_050E: 20240607_17_16_16
# Requesting data in chunk -90_-40_-88_-38 in 30S_090W: 20240607_17_16_16
# Requesting data in chunk -14_36_-12_38 in 40N_020W: 20240607_17_16_16
# Requesting data in chunk 72_28_74_30 in 30N_070E: 20240607_17_16_17
# Requesting data in chunk 136_-38_138_-36 in 30S_130E: 20240607_17_16_17
# Requesting data in chunk -112_76_-110_78 in 80N_120W: 20240607_17_16_17
# Requesting data in chunk 42_58_44_60 in 60N_040E: 20240607_17_16_17
# Requesting data in chunk -130_46_-128_48 in 50N_130W: 20240607_17_16_17
# Requesting data in chunk 142_38_144_40 in 40N_140E: 20240607_17_16_17
# Requesting data in chunk -58_0_-56_2 in 10N_060W: 20240607_17_16_17
# Requesting data in chunk 150_40_152_42 in 50N_150E: 20240607_17_16_17
# Requesting data in chunk -106_18_-104_20 in 20N_110W: 20240607_17_16_17
# Requesting data in chunk 86_32_88_34 in 40N_080E: 20240607_17_16_17
# Requesting data in chunk -16_26_-14_28 in 30N_020W: 20240607_17_16_17
# Requesting data in chunk 8_66_10_68 in 70N_000E: 20240607_17_16_17
# Requesting data in chunk 124_-26_126_-24 in 20S_120E: 20240607_17_16_17
# Requesting data in chunk -114_24_-112_26 in 30N_120W: 20240607_17_16_17
# Requesting data in chunk 76_24_78_26 in 30N_070E: 20240607_17_16_17
# Requesting data in chunk 14_48_16_50 in 50N_010E: 20240607_17_16_17
# Requesting data in chunk 60_54_62_56 in 60N_060E: 20240607_17_16_17
# Requesting data in chunk 146_42_148_44 in 50N_140E: 20240607_17_16_17
# Requesting data in chunk 100_28_102_30 in 30N_100E: 20240607_17_16_17
# Requesting data in chunk 136_56_138_58 in 60N_130E: 20240607_17_16_17
# Requesting data in chunk -82_-10_-80_-8 in 00N_090W: 20240607_17_16_17
# Requesting data in chunk -96_48_-94_50 in 50N_100W: 20240607_17_16_17
# Requesting data in chunk 140_66_142_68 in 70N_140E: 20240607_17_16_17
# Requesting data in chunk 24_68_26_70 in 70N_020E: 20240607_17_16_17
# Requesting data in chunk 52_8_54_10 in 10N_050E: 20240607_17_16_17
# Requesting data in chunk 22_-36_24_-34 in 30S_020E: 20240607_17_16_17
# Requesting data in chunk 152_68_154_70 in 70N_150E: 20240607_17_16_17
# Requesting data in chunk -92_64_-90_66 in 70N_100W: 20240607_17_16_17
# Requesting data in chunk 174_72_176_74 in 80N_170E: 20240607_17_16_17
# Requesting data in chunk 162_74_164_76 in 80N_160E: 20240607_17_16_17
# Requesting data in chunk -74_-26_-72_-24 in 20S_080W: 20240607_17_16_17
# Requesting data in chunk -76_40_-74_42 in 50N_080W: 20240607_17_16_17
# Requesting data in chunk -120_22_-118_24 in 30N_120W: 20240607_17_16_17
# Requesting data in chunk 144_52_146_54 in 60N_140E: 20240607_17_16_17
# Requesting data in chunk 156_-8_158_-6 in 00N_150E: 20240607_17_16_17
# Requesting data in chunk 86_2_88_4 in 10N_080E: 20240607_17_16_17
# Requesting data in chunk 174_-36_176_-34 in 30S_170E: 20240607_17_16_17
# Requesting data in chunk 38_38_40_40 in 40N_030E: 20240607_17_16_17
# Requesting data in chunk 114_8_116_10 in 10N_110E: 20240607_17_16_17
# Requesting data in chunk 24_-36_26_-34 in 30S_020E: 20240607_17_16_17
# Requesting data in chunk 10_8_12_10 in 10N_010E: 20240607_17_16_17
# Requesting data in chunk 14_74_16_76 in 80N_010E: 20240607_17_16_17
# Requesting data in chunk 10_52_12_54 in 60N_010E: 20240607_17_16_17
# Requesting data in chunk 52_34_54_36 in 40N_050E: 20240607_17_16_17
# Requesting data in chunk 42_60_44_62 in 70N_040E: 20240607_17_16_17
# Requesting data in chunk 58_74_60_76 in 80N_050E: 20240607_17_16_17
# Requesting data in chunk -100_16_-98_18 in 20N_100W: 20240607_17_16_17
# Requesting data in chunk 34_-10_36_-8 in 00N_030E: 20240607_17_16_17
# Requesting data in chunk 36_20_38_22 in 30N_030E: 20240607_17_16_17
# Requesting data in chunk -66_-18_-64_-16 in 10S_070W: 20240607_17_16_17
# Requesting data in chunk -14_24_-12_26 in 30N_020W: 20240607_17_16_17
# Requesting data in chunk 116_52_118_54 in 60N_110E: 20240607_17_16_17
# Requesting data in chunk -78_-52_-76_-50 in 50S_080W: 20240607_17_16_17
# Requesting data in chunk -58_40_-56_42 in 50N_060W: 20240607_17_16_17
# Requesting data in chunk -12_24_-10_26 in 30N_020W: 20240607_17_16_17
# Requesting data in chunk 28_54_30_56 in 60N_020E: 20240607_17_16_17
# Requesting data in chunk 150_-34_152_-32 in 30S_150E: 20240607_17_16_17
# Requesting data in chunk -18_16_-16_18 in 20N_020W: 20240607_17_16_17
# Requesting data in chunk 48_54_50_56 in 60N_040E: 20240607_17_16_17
# Requesting data in chunk 48_22_50_24 in 30N_040E: 20240607_17_16_17
# Requesting data in chunk -66_36_-64_38 in 40N_070W: 20240607_17_16_17
# Requesting data in chunk -14_14_-12_16 in 20N_020W: 20240607_17_16_17
# Requesting data in chunk 96_58_98_60 in 60N_090E: 20240607_17_16_17
# Requesting data in chunk 146_46_148_48 in 50N_140E: 20240607_17_16_17
# Requesting data in chunk 20_-38_22_-36 in 30S_020E: 20240607_17_16_17
# Requesting data in chunk 134_2_136_4 in 10N_130E: 20240607_17_16_17
# Requesting data in chunk -102_26_-100_28 in 30N_110W: 20240607_17_16_17
# Requesting data in chunk 38_78_40_80 in 80N_030E: 20240607_17_16_17
# Requesting data in chunk -54_-18_-52_-16 in 10S_060W: 20240607_17_16_17
# Requesting data in chunk -48_-12_-46_-10 in 10S_050W: 20240607_17_16_17
# Requesting data in chunk 10_20_12_22 in 30N_010E: 20240607_17_16_17
# Requesting data in chunk -124_50_-122_52 in 60N_130W: 20240607_17_16_17
# Requesting data in chunk -78_-60_-76_-58 in 50S_080W: 20240607_17_16_17
# Requesting data in chunk -88_56_-86_58 in 60N_090W: 20240607_17_16_17
# Requesting data in chunk 72_10_74_12 in 20N_070E: 20240607_17_16_17
# Requesting data in chunk 152_66_154_68 in 70N_150E: 20240607_17_16_17
# Requesting data in chunk 42_-24_44_-22 in 20S_040E: 20240607_17_16_17
# Requesting data in chunk 38_-12_40_-10 in 10S_030E: 20240607_17_16_17
# Requesting data in chunk 82_26_84_28 in 30N_080E: 20240607_17_16_17
# Requesting data in chunk 0_44_2_46 in 50N_000E: 20240607_17_16_17
# Requesting data in chunk 22_46_24_48 in 50N_020E: 20240607_17_16_17
# Requesting data in chunk -102_-24_-100_-22 in 20S_110W: 20240607_17_16_17
# Requesting data in chunk 54_58_56_60 in 60N_050E: 20240607_17_16_17
# Requesting data in chunk 76_54_78_56 in 60N_070E: 20240607_17_16_17
# Requesting data in chunk 162_-24_164_-22 in 20S_160E: 20240607_17_16_17
# Requesting data in chunk -44_-30_-42_-28 in 20S_050W: 20240607_17_16_17
# Requesting data in chunk 134_-34_136_-32 in 30S_130E: 20240607_17_16_17
# Requesting data in chunk 66_76_68_78 in 80N_060E: 20240607_17_16_17
# Requesting data in chunk 40_38_42_40 in 40N_040E: 20240607_17_16_17
# Requesting data in chunk -84_60_-82_62 in 70N_090W: 20240607_17_16_17
# Requesting data in chunk 36_-16_38_-14 in 10S_030E: 20240607_17_16_17
# Requesting data in chunk -60_-60_-58_-58 in 50S_060W: 20240607_17_16_17
# Requesting data in chunk -62_4_-60_6 in 10N_070W: 20240607_17_16_16
# Requesting data in chunk -68_66_-66_68 in 70N_070W: 20240607_17_16_16
# Requesting data in chunk -72_-20_-70_-18 in 10S_080W: 20240607_17_16_16
# Requesting data in chunk 12_-28_14_-26 in 20S_010E: 20240607_17_16_16
# Requesting data in chunk -10_10_-8_12 in 20N_010W: 20240607_17_16_16
# Requesting data in chunk -64_60_-62_62 in 70N_070W: 20240607_17_16_16
# Requesting data in chunk -2_46_0_48 in 50N_010W: 20240607_17_16_16
# Requesting data in chunk 76_56_78_58 in 60N_070E: 20240607_17_16_16
# Requesting data in chunk 14_24_16_26 in 30N_010E: 20240607_17_16_16
# Requesting data in chunk 0_-6_2_-4 in 00N_000E: 20240607_17_16_16
# Requesting data in chunk -104_-24_-102_-22 in 20S_110W: 20240607_17_16_18
# Requesting data in chunk -76_42_-74_44 in 50N_080W: 20240607_17_16_18
# Requesting data in chunk 160_78_162_80 in 80N_160E: 20240607_17_16_17
# Requesting data in chunk 150_48_152_50 in 50N_150E: 20240607_17_16_17
# Requesting data in chunk 110_36_112_38 in 40N_110E: 20240607_17_16_17
# Requesting data in chunk 110_-12_112_-10 in 10S_110E: 20240607_17_16_17
# Requesting data in chunk -50_-4_-48_-2 in 00N_050W: 20240607_17_16_17
# Requesting data in chunk 138_-32_140_-30 in 30S_130E: 20240607_17_16_17
# Requesting data in chunk 56_14_58_16 in 20N_050E: 20240607_17_16_18
# Requesting data in chunk -86_8_-84_10 in 10N_090W: 20240607_17_16_17
# Requesting data in chunk 104_26_106_28 in 30N_100E: 20240607_17_16_17
# Requesting data in chunk 136_2_138_4 in 10N_130E: 20240607_17_16_18
# Requesting data in chunk 14_-4_16_-2 in 00N_010E: 20240607_17_16_18
# Requesting data in chunk -152_74_-150_76 in 80N_160W: 20240607_17_16_18
# Requesting data in chunk -108_-30_-106_-28 in 20S_110W: 20240607_17_16_18
# Requesting data in chunk -4_66_-2_68 in 70N_010W: 20240607_17_16_17
# Requesting data in chunk -28_62_-26_64 in 70N_030W: 20240607_17_16_18
# Requesting data in chunk -106_36_-104_38 in 40N_110W: 20240607_17_16_18
# Requesting data in chunk 88_36_90_38 in 40N_080E: 20240607_17_16_18
# Requesting data in chunk 132_24_134_26 in 30N_130E: 20240607_17_16_18
# Requesting data in chunk -104_34_-102_36 in 40N_110W: 20240607_17_16_18
# Requesting data in chunk -92_52_-90_54 in 60N_100W: 20240607_17_16_18
# Requesting data in chunk 4_10_6_12 in 20N_000E: 20240607_17_16_17
# Requesting data in chunk 76_8_78_10 in 10N_070E: 20240607_17_16_17
# Requesting data in chunk 174_-50_176_-48 in 40S_170E: 20240607_17_16_18
# Requesting data in chunk -124_72_-122_74 in 80N_130W: 20240607_17_16_17
# Requesting data in chunk 64_78_66_80 in 80N_060E: 20240607_17_16_17
# Requesting data in chunk 108_62_110_64 in 70N_100E: 20240607_17_16_17
# Requesting data in chunk -152_16_-150_18 in 20N_160W: 20240607_17_16_18
# Requesting data in chunk -70_56_-68_58 in 60N_070W: 20240607_17_16_18
# Requesting data in chunk -6_62_-4_64 in 70N_010W: 20240607_17_16_18
# Requesting data in chunk -68_30_-66_32 in 40N_070W: 20240607_17_16_18
# Requesting data in chunk 142_70_144_72 in 80N_140E: 20240607_17_16_18
# Requesting data in chunk 144_60_146_62 in 70N_140E: 20240607_17_16_18
# Requesting data in chunk 160_68_162_70 in 70N_160E: 20240607_17_16_17
# Requesting data in chunk -70_-60_-68_-58 in 50S_070W: 20240607_17_16_17
# Requesting data in chunk 74_12_76_14 in 20N_070E: 20240607_17_16_17
# Requesting data in chunk 118_20_120_22 in 30N_110E: 20240607_17_16_17
# Requesting data in chunk 44_6_46_8 in 10N_040E: 20240607_17_16_17
# Requesting data in chunk 56_18_58_20 in 20N_050E: 20240607_17_16_17
# Requesting data in chunk 92_36_94_38 in 40N_090E: 20240607_17_16_17
# Requesting data in chunk -68_62_-66_64 in 70N_070W: 20240607_17_16_17
# Requesting data in chunk -158_78_-156_80 in 80N_160W: 20240607_17_16_17
# Requesting data in chunk 120_-6_122_-4 in 00N_120E: 20240607_17_16_17
# Requesting data in chunk 16_32_18_34 in 40N_010E: 20240607_17_16_18
# Requesting data in chunk 36_-26_38_-24 in 20S_030E: 20240607_17_16_18
# Requesting data in chunk 90_50_92_52 in 60N_090E: 20240607_17_16_18
# Requesting data in chunk -80_-52_-78_-50 in 50S_080W: 20240607_17_16_18
# Requesting data in chunk 14_-34_16_-32 in 30S_010E: 20240607_17_16_18
# Requesting data in chunk -68_60_-66_62 in 70N_070W: 20240607_17_16_18
# Requesting data in chunk 22_14_24_16 in 20N_020E: 20240607_17_16_18
# Requesting data in chunk 100_48_102_50 in 50N_100E: 20240607_17_16_18
# Requesting data in chunk 132_-38_134_-36 in 30S_130E: 20240607_17_16_18
# Requesting data in chunk 80_12_82_14 in 20N_080E: 20240607_17_16_18
# Requesting data in chunk 38_68_40_70 in 70N_030E: 20240607_17_16_18
# Requesting data in chunk -92_6_-90_8 in 10N_100W: 20240607_17_16_18
# Requesting data in chunk -16_20_-14_22 in 30N_020W: 20240607_17_16_18
# Requesting data in chunk 136_8_138_10 in 10N_130E: 20240607_17_16_18
# Requesting data in chunk 104_40_106_42 in 50N_100E: 20240607_17_16_18
# Requesting data in chunk -72_26_-70_28 in 30N_080W: 20240607_17_16_18
# Requesting data in chunk -120_30_-118_32 in 40N_120W: 20240607_17_16_18
# Requesting data in chunk -8_32_-6_34 in 40N_010W: 20240607_17_16_18
# Requesting data in chunk 36_0_38_2 in 10N_030E: 20240607_17_16_18
# Requesting data in chunk 40_-24_42_-22 in 20S_040E: 20240607_17_16_18
# Requesting data in chunk -76_44_-74_46 in 50N_080W: 20240607_17_16_17
# Requesting data in chunk 66_62_68_64 in 70N_060E: 20240607_17_16_18
# Requesting data in chunk -52_42_-50_44 in 50N_060W: 20240607_17_16_18
# Requesting data in chunk -66_-12_-64_-10 in 10S_070W: 20240607_17_16_18
# Requesting data in chunk -96_66_-94_68 in 70N_100W: 20240607_17_16_18
# Requesting data in chunk -92_34_-90_36 in 40N_100W: 20240607_17_16_18
# Requesting data in chunk 112_68_114_70 in 70N_110E: 20240607_17_16_18
# Requesting data in chunk 130_6_132_8 in 10N_130E: 20240607_17_16_18
# Requesting data in chunk 156_-12_158_-10 in 10S_150E: 20240607_17_16_18
# Requesting data in chunk -36_-14_-34_-12 in 10S_040W: 20240607_17_16_18
# Requesting data in chunk 66_52_68_54 in 60N_060E: 20240607_17_16_18
# Requesting data in chunk -18_32_-16_34 in 40N_020W: 20240607_17_16_17
# Requesting data in chunk 36_60_38_62 in 70N_030E: 20240607_17_16_17
# Requesting data in chunk 30_-14_32_-12 in 10S_030E: 20240607_17_16_17
# Requesting data in chunk -16_34_-14_36 in 40N_020W: 20240607_17_16_17
# Requesting data in chunk 98_40_100_42 in 50N_090E: 20240607_17_16_17
# Requesting data in chunk 102_60_104_62 in 70N_100E: 20240607_17_16_17
# Requesting data in chunk 142_-38_144_-36 in 30S_140E: 20240607_17_16_18
# Requesting data in chunk 124_22_126_24 in 30N_120E: 20240607_17_16_18
# Requesting data in chunk 154_60_156_62 in 70N_150E: 20240607_17_16_18
# Requesting data in chunk 74_64_76_66 in 70N_070E: 20240607_17_16_18
# Requesting data in chunk 80_36_82_38 in 40N_080E: 20240607_17_16_18
# Requesting data in chunk 128_-36_130_-34 in 30S_120E: 20240607_17_16_18
# Requesting data in chunk 68_64_70_66 in 70N_060E: 20240607_17_16_18
# Requesting data in chunk 118_42_120_44 in 50N_110E: 20240607_17_16_18
# Requesting data in chunk -90_24_-88_26 in 30N_090W: 20240607_17_16_18
# Requesting data in chunk -22_10_-20_12 in 20N_030W: 20240607_17_16_18
# Requesting data in chunk 44_20_46_22 in 30N_040E: 20240607_17_16_18
# Requesting data in chunk 118_18_120_20 in 20N_110E: 20240607_17_16_18
# Requesting data in chunk -76_8_-74_10 in 10N_080W: 20240607_17_16_18
# Requesting data in chunk 42_36_44_38 in 40N_040E: 20240607_17_16_18
# Requesting data in chunk 100_62_102_64 in 70N_100E: 20240607_17_16_18
# Requesting data in chunk 124_60_126_62 in 70N_120E: 20240607_17_16_18
# Requesting data in chunk -12_62_-10_64 in 70N_020W: 20240607_17_16_18
# Requesting data in chunk 112_-12_114_-10 in 10S_110E: 20240607_17_16_18
# Requesting data in chunk -88_38_-86_40 in 40N_090W: 20240607_17_16_18
# Requesting data in chunk -154_24_-152_26 in 30N_160W: 20240607_17_16_18
# Requesting data in chunk 30_50_32_52 in 60N_030E: 20240607_17_16_18
# Requesting data in chunk -96_16_-94_18 in 20N_100W: 20240607_17_16_18
# Requesting data in chunk -52_-12_-50_-10 in 10S_060W: 20240607_17_16_18
# Requesting data in chunk -154_78_-152_80 in 80N_160W: 20240607_17_16_18
# Requesting data in chunk 154_-14_156_-12 in 10S_150E: 20240607_17_16_18
# Requesting data in chunk 34_66_36_68 in 70N_030E: 20240607_17_16_18
# Requesting data in chunk 100_12_102_14 in 20N_100E: 20240607_17_16_18
# Requesting data in chunk 142_8_144_10 in 10N_140E: 20240607_17_16_18
# Requesting data in chunk 128_62_130_64 in 70N_120E: 20240607_17_16_18
# Requesting data in chunk 122_-22_124_-20 in 20S_120E: 20240607_17_16_18
# Requesting data in chunk -122_30_-120_32 in 40N_130W: 20240607_17_16_18
# Requesting data in chunk 120_56_122_58 in 60N_120E: 20240607_17_16_18
# Requesting data in chunk -156_58_-154_60 in 60N_160W: 20240607_17_16_18
# Requesting data in chunk 28_-10_30_-8 in 00N_020E: 20240607_17_16_18
# Requesting data in chunk -96_-6_-94_-4 in 00N_100W: 20240607_17_16_18
# Requesting data in chunk -80_2_-78_4 in 10N_080W: 20240607_17_16_18
# Requesting data in chunk 30_2_32_4 in 10N_030E: 20240607_17_16_18
# Requesting data in chunk -110_52_-108_54 in 60N_110W: 20240607_17_16_18
# Requesting data in chunk -70_18_-68_20 in 20N_070W: 20240607_17_16_19
# Requesting data in chunk 0_32_2_34 in 40N_000E: 20240607_17_16_19
# Requesting data in chunk 10_34_12_36 in 40N_010E: 20240607_17_16_19
# Requesting data in chunk -80_-20_-78_-18 in 10S_080W: 20240607_17_16_19
# Requesting data in chunk 106_40_108_42 in 50N_100E: 20240607_17_16_18
# Requesting data in chunk -62_-28_-60_-26 in 20S_070W: 20240607_17_16_19
# Requesting data in chunk 10_32_12_34 in 40N_010E: 20240607_17_16_19
# Requesting data in chunk 78_62_80_64 in 70N_070E: 20240607_17_16_19
# Requesting data in chunk -96_64_-94_66 in 70N_100W: 20240607_17_16_19
# Requesting data in chunk -130_64_-128_66 in 70N_130W: 20240607_17_16_19
# Requesting data in chunk -60_-30_-58_-28 in 20S_060W: 20240607_17_16_19
# Requesting data in chunk 68_70_70_72 in 80N_060E: 20240607_17_16_18
# Requesting data in chunk -78_74_-76_76 in 80N_080W: 20240607_17_16_18
# Requesting data in chunk -130_74_-128_76 in 80N_130W: 20240607_17_16_19
# Requesting data in chunk 26_-16_28_-14 in 10S_020E: 20240607_17_16_19
# Requesting data in chunk 20_66_22_68 in 70N_020E: 20240607_17_16_18
# Requesting data in chunk 20_-16_22_-14 in 10S_020E: 20240607_17_16_18
# Requesting data in chunk 126_-32_128_-30 in 30S_120E: 20240607_17_16_18
# Requesting data in chunk 108_52_110_54 in 60N_100E: 20240607_17_16_18
# Requesting data in chunk -168_62_-166_64 in 70N_170W: 20240607_17_16_18
# Requesting data in chunk 84_52_86_54 in 60N_080E: 20240607_17_16_19
# Requesting data in chunk 134_56_136_58 in 60N_130E: 20240607_17_16_19
# Requesting data in chunk -86_38_-84_40 in 40N_090W: 20240607_17_16_19
# Requesting data in chunk 154_-4_156_-2 in 00N_150E: 20240607_17_16_19
# Requesting data in chunk -98_10_-96_12 in 20N_100W: 20240607_17_16_19
# Requesting data in chunk 18_-8_20_-6 in 00N_010E: 20240607_17_16_19
# Requesting data in chunk -82_32_-80_34 in 40N_090W: 20240607_17_16_19
# Requesting data in chunk 30_16_32_18 in 20N_030E: 20240607_17_16_19
# Requesting data in chunk 32_-30_34_-28 in 20S_030E: 20240607_17_16_19
# Requesting data in chunk 66_48_68_50 in 50N_060E: 20240607_17_16_19
# Requesting data in chunk 136_6_138_8 in 10N_130E: 20240607_17_16_19
# Requesting data in chunk -28_66_-26_68 in 70N_030W: 20240607_17_16_19
# Requesting data in chunk 22_-2_24_0 in 00N_020E: 20240607_17_16_19
# Requesting data in chunk 128_50_130_52 in 60N_120E: 20240607_17_16_19
# Requesting data in chunk 144_32_146_34 in 40N_140E: 20240607_17_16_19
# Requesting data in chunk -80_28_-78_30 in 30N_080W: 20240607_17_16_19
# Requesting data in chunk 90_54_92_56 in 60N_090E: 20240607_17_16_19
# Requesting data in chunk -124_56_-122_58 in 60N_130W: 20240607_17_16_19
# Requesting data in chunk -16_4_-14_6 in 10N_020W: 20240607_17_16_19
# Requesting data in chunk 140_6_142_8 in 10N_140E: 20240607_17_16_19
# Requesting data in chunk 140_-22_142_-20 in 20S_140E: 20240607_17_16_20
# Requesting data in chunk 100_22_102_24 in 30N_100E: 20240607_17_16_20
# Requesting data in chunk 132_64_134_66 in 70N_130E: 20240607_17_17_05
# Requesting data in chunk -10_58_-8_60 in 60N_010W: 20240607_17_17_06
# Requesting data in chunk 78_72_80_74 in 80N_070E: 20240607_17_17_10
# Requesting data in chunk -136_60_-134_62 in 70N_140W: 20240607_17_17_11
# Requesting data in chunk 64_24_66_26 in 30N_060E: 20240607_17_17_11
# Requesting data in chunk 158_70_160_72 in 80N_150E: 20240607_17_17_13
# Requesting data in chunk -12_52_-10_54 in 60N_020W: 20240607_17_17_14
# Requesting data in chunk 118_-40_120_-38 in 30S_110E: 20240607_17_17_14
# Requesting data in chunk 14_42_16_44 in 50N_010E: 20240607_17_17_15
# Requesting data in chunk -72_-34_-70_-32 in 30S_080W: 20240607_17_17_15
# Requesting data in chunk 14_-18_16_-16 in 10S_010E: 20240607_17_17_16
# Requesting data in chunk 154_74_156_76 in 80N_150E: 20240607_17_17_17
# Requesting data in chunk 54_74_56_76 in 80N_050E: 20240607_17_17_17
# Requesting data in chunk 146_-4_148_-2 in 00N_140E: 20240607_17_17_18
# Requesting data in chunk 24_-6_26_-4 in 00N_020E: 20240607_17_17_19
# Requesting data in chunk -66_-20_-64_-18 in 10S_070W: 20240607_17_17_19
# Requesting data in chunk 108_-6_110_-4 in 00N_100E: 20240607_17_17_07
# Requesting data in chunk 16_52_18_54 in 60N_010E: 20240607_17_17_20
# Requesting data in chunk 72_48_74_50 in 50N_070E: 20240607_17_17_20
# Requesting data in chunk 90_-8_92_-6 in 00N_090E: 20240607_17_17_20
# Requesting data in chunk -162_22_-160_24 in 30N_170W: 20240607_17_17_20
# Requesting data in chunk -58_-30_-56_-28 in 20S_060W: 20240607_17_17_20
# Requesting data in chunk 124_68_126_70 in 70N_120E: 20240607_17_17_20
# Requesting data in chunk 86_54_88_56 in 60N_080E: 20240607_17_17_20
# Requesting data in chunk 22_62_24_64 in 70N_020E: 20240607_17_17_20
# Requesting data in chunk 166_-30_168_-28 in 20S_160E: 20240607_17_17_20
# Requesting data in chunk 154_-40_156_-38 in 30S_150E: 20240607_17_17_20
# Requesting data in chunk -4_32_-2_34 in 40N_010W: 20240607_17_17_17
# Requesting data in chunk -32_-6_-30_-4 in 00N_040W: 20240607_17_17_20
# Requesting data in chunk -32_-14_-30_-12 in 10S_040W: 20240607_17_17_21
# Requesting data in chunk 44_30_46_32 in 40N_040E: 20240607_17_17_21
# Requesting data in chunk 14_76_16_78 in 80N_010E: 20240607_17_17_19
# Requesting data in chunk -22_64_-20_66 in 70N_030W: 20240607_17_17_21
# Requesting data in chunk 156_60_158_62 in 70N_150E: 20240607_17_17_21
# Requesting data in chunk 46_-20_48_-18 in 10S_040E: 20240607_17_17_21
# Requesting data in chunk 138_-16_140_-14 in 10S_130E: 20240607_17_17_21
# Requesting data in chunk 46_38_48_40 in 40N_040E: 20240607_17_17_21
# Requesting data in chunk 20_-22_22_-20 in 20S_020E: 20240607_17_17_21
# Requesting data in chunk 26_-30_28_-28 in 20S_020E: 20240607_17_17_21
# Requesting data in chunk -146_66_-144_68 in 70N_150W: 20240607_17_17_21
# Requesting data in chunk -80_42_-78_44 in 50N_080W: 20240607_17_17_21
# Requesting data in chunk 112_32_114_34 in 40N_110E: 20240607_17_17_21
# Requesting data in chunk 48_44_50_46 in 50N_040E: 20240607_17_17_21
# Requesting data in chunk 100_26_102_28 in 30N_100E: 20240607_17_17_22
# Requesting data in chunk 118_58_120_60 in 60N_110E: 20240607_17_17_22
# Requesting data in chunk -44_-28_-42_-26 in 20S_050W: 20240607_17_17_14
# Requesting data in chunk -76_50_-74_52 in 60N_080W: 20240607_17_17_14
# ...
# Requesting data in chunk -52_54_-50_56 in 60N_060W: 20240607_17_27_35
# Requesting data in chunk 116_64_118_66 in 70N_110E: 20240607_17_27_35
# Requesting data in chunk 64_52_66_54 in 60N_060E: 20240607_17_27_35
# Requesting data in chunk -72_30_-70_32 in 40N_080W: 20240607_17_27_35
# Requesting data in chunk -172_50_-170_52 in 60N_180W: 20240607_17_27_34
# Requesting data in chunk 130_20_132_22 in 30N_130E: 20240607_17_27_30
# Requesting data in chunk -90_0_-88_2 in 10N_090W: 20240607_17_27_30
# Requesting data in chunk -66_58_-64_60 in 60N_070W: 20240607_17_27_30
# Requesting data in chunk -74_-10_-72_-8 in 00N_080W: 20240607_17_27_33
# Requesting data in chunk 110_-32_112_-30 in 30S_110E: 20240607_17_27_34
# Requesting data in chunk 44_46_46_48 in 50N_040E: 20240607_17_27_35
# Requesting data in chunk 162_-14_164_-12 in 10S_160E: 20240607_17_27_35
# Requesting data in chunk 130_58_132_60 in 60N_130E: 20240607_17_27_35
# Requesting data in chunk -172_56_-170_58 in 60N_180W: 20240607_17_27_35
# Requesting data in chunk -122_54_-120_56 in 60N_130W: 20240607_17_27_35
# Requesting data in chunk 30_-4_32_-2 in 00N_030E: 20240607_17_27_34
# Requesting data in chunk 152_44_154_46 in 50N_150E: 20240607_17_27_36
# Requesting data in chunk 34_-12_36_-10 in 10S_030E: 20240607_17_27_31
# Requesting data in chunk 120_58_122_60 in 60N_120E: 20240607_17_27_32
# Requesting data in chunk -106_14_-104_16 in 20N_110W: 20240607_17_27_32
# Requesting data in chunk 126_-2_128_0 in 00N_120E: 20240607_17_27_36
# Requesting data in chunk -16_68_-14_70 in 70N_020W: 20240607_17_27_36
# Requesting data in chunk 32_22_34_24 in 30N_030E: 20240607_17_27_36
# Requesting data in chunk 122_16_124_18 in 20N_120E: 20240607_17_27_36
# Requesting data in chunk -82_58_-80_60 in 60N_090W: 20240607_17_27_36
# Requesting data in chunk 126_-36_128_-34 in 30S_120E: 20240607_17_27_36
# Requesting data in chunk 116_-36_118_-34 in 30S_110E: 20240607_17_27_35
# Requesting data in chunk -24_62_-22_64 in 70N_030W: 20240607_17_27_30
# Requesting data in chunk 142_-26_144_-24 in 20S_140E: 20240607_17_27_36
# Requesting data in chunk -94_2_-92_4 in 10N_100W: 20240607_17_27_36
# Requesting data in chunk 14_-2_16_0 in 00N_010E: 20240607_17_27_22
# Requesting data in chunk -102_76_-100_78 in 80N_110W: 20240607_17_27_27
# Requesting data in chunk -104_24_-102_26 in 30N_110W: 20240607_17_27_27
# Requesting data in chunk -100_-6_-98_-4 in 00N_100W: 20240607_17_27_27
# Requesting data in chunk 132_62_134_64 in 70N_130E: 20240607_17_27_36
# Requesting data in chunk 130_26_132_28 in 30N_130E: 20240607_17_27_36
# Requesting data in chunk -62_-54_-60_-52 in 50S_070W: 20240607_17_27_28
# Requesting data in chunk 92_64_94_66 in 70N_090E: 20240607_17_27_35
# Requesting data in chunk 126_20_128_22 in 30N_120E: 20240607_17_27_37
# Requesting data in chunk 98_56_100_58 in 60N_090E: 20240607_17_27_33
# Requesting data in chunk 118_30_120_32 in 40N_110E: 20240607_17_27_37
# Requesting data in chunk 16_26_18_28 in 30N_010E: 20240607_17_27_35
# Requesting data in chunk -180_62_-178_64 in 70N_180W: 20240607_17_27_35
# Requesting data in chunk 144_-34_146_-32 in 30S_140E: 20240607_17_27_36
# Requesting data in chunk 40_-14_42_-12 in 10S_040E: 20240607_17_27_37
# Requesting data in chunk 164_74_166_76 in 80N_160E: 20240607_17_27_37
# Requesting data in chunk 76_38_78_40 in 40N_070E: 20240607_17_27_37
# Requesting data in chunk -18_36_-16_38 in 40N_020W: 20240607_17_27_38
# Requesting data in chunk -88_36_-86_38 in 40N_090W: 20240607_17_27_32
# Requesting data in chunk -20_38_-18_40 in 40N_020W: 20240607_17_27_37
# Requesting data in chunk -82_38_-80_40 in 40N_090W: 20240607_17_27_37
# Requesting data in chunk -114_64_-112_66 in 70N_120W: 20240607_17_27_37
# Requesting data in chunk -60_0_-58_2 in 10N_060W: 20240607_17_27_38
# Requesting data in chunk 78_20_80_22 in 30N_070E: 20240607_17_27_37
# Requesting data in chunk 28_-12_30_-10 in 10S_020E: 20240607_17_27_39
# Requesting data in chunk -100_30_-98_32 in 40N_100W: 20240607_17_27_27
# Requesting data in chunk -12_58_-10_60 in 60N_020W: 20240607_17_27_27
# Requesting data in chunk 128_48_130_50 in 50N_120E: 20240607_17_27_27
# Requesting data in chunk 110_14_112_16 in 20N_110E: 20240607_17_27_30
# Requesting data in chunk -170_52_-168_54 in 60N_170W: 20240607_17_27_37
# Requesting data in chunk 22_4_24_6 in 10N_020E: 20240607_17_27_39
# Requesting data in chunk 134_-30_136_-28 in 20S_130E: 20240607_17_27_28
# Requesting data in chunk 26_-8_28_-6 in 00N_020E: 20240607_17_27_29
# Requesting data in chunk -38_-4_-36_-2 in 00N_040W: 20240607_17_27_29
# Requesting data in chunk 100_-18_102_-16 in 10S_100E: 20240607_17_27_40
# Requesting data in chunk 162_-2_164_0 in 00N_160E: 20240607_17_27_29
# Requesting data in chunk 134_44_136_46 in 50N_130E: 20240607_17_27_29
# Requesting data in chunk 100_-12_102_-10 in 10S_100E: 20240607_17_27_39
# Requesting data in chunk 162_66_164_68 in 70N_160E: 20240607_17_27_40
# Requesting data in chunk 46_36_48_38 in 40N_040E: 20240607_17_27_32
# Requesting data in chunk 140_-4_142_-2 in 00N_140E: 20240607_17_27_32
# Requesting data in chunk -158_20_-156_22 in 30N_160W: 20240607_17_27_32
# Requesting data in chunk 74_34_76_36 in 40N_070E: 20240607_17_27_33
# Requesting data in chunk -94_38_-92_40 in 40N_100W: 20240607_17_27_41
# Requesting data in chunk -152_62_-150_64 in 70N_160W: 20240607_17_27_33
# Requesting data in chunk -66_2_-64_4 in 10N_070W: 20240607_17_27_42
# Requesting data in chunk 156_-20_158_-18 in 10S_150E: 20240607_17_27_32
# Requesting data in chunk -86_12_-84_14 in 20N_090W: 20240607_17_27_36
# Requesting data in chunk 102_22_104_24 in 30N_100E: 20240607_17_27_43
# Requesting data in chunk -108_52_-106_54 in 60N_110W: 20240607_17_27_43
# Requesting data in chunk -92_-2_-90_0 in 00N_100W: 20240607_17_27_38
# Requesting data in chunk 90_78_92_80 in 80N_090E: 20240607_17_27_35
# Requesting data in chunk 38_-28_40_-26 in 20S_030E: 20240607_17_27_35
# Requesting data in chunk -58_-16_-56_-14 in 10S_060W: 20240607_17_27_43
# Requesting data in chunk -78_-50_-76_-48 in 40S_080W: 20240607_17_27_33
# Requesting data in chunk 112_50_114_52 in 60N_110E: 20240607_17_27_34
# Requesting data in chunk -164_58_-162_60 in 60N_170W: 20240607_17_27_38
# Requesting data in chunk -52_-28_-50_-26 in 20S_060W: 20240607_17_27_44
# Requesting data in chunk 176_-44_178_-42 in 40S_170E: 20240607_17_27_44
# Requesting data in chunk 56_-18_58_-16 in 10S_050E: 20240607_17_27_38
# Requesting data in chunk 98_-4_100_-2 in 00N_090E: 20240607_17_27_43
# Requesting data in chunk -122_66_-120_68 in 70N_130W: 20240607_17_27_42
# Requesting data in chunk 144_-6_146_-4 in 00N_140E: 20240607_17_27_42
# Requesting data in chunk 114_-22_116_-20 in 20S_110E: 20240607_17_27_42
# Requesting data in chunk 138_38_140_40 in 40N_130E: 20240607_17_27_31
# Requesting data in chunk -128_76_-126_78 in 80N_130W: 20240607_17_27_32
# Requesting data in chunk -178_52_-176_54 in 60N_180W: 20240607_17_27_37
# Requesting data in chunk -104_40_-102_42 in 50N_110W: 20240607_17_27_36
# Requesting data in chunk 62_74_64_76 in 80N_060E: 20240607_17_27_47
# Requesting data in chunk -38_-18_-36_-16 in 10S_040W: 20240607_17_27_47
# Requesting data in chunk -56_46_-54_48 in 50N_060W: 20240607_17_27_33
# Requesting data in chunk 146_78_148_80 in 80N_140E: 20240607_17_27_33
# Requesting data in chunk 70_34_72_36 in 40N_070E: 20240607_17_27_48
# Requesting data in chunk 30_64_32_66 in 70N_030E: 20240607_17_27_46
# Requesting data in chunk -94_22_-92_24 in 30N_100W: 20240607_17_27_46
# Requesting data in chunk 26_-22_28_-20 in 20S_020E: 20240607_17_27_37
# Requesting data in chunk -48_-14_-46_-12 in 10S_050W: 20240607_17_27_37
# Requesting data in chunk 60_70_62_72 in 80N_060E: 20240607_17_27_37
# Requesting data in chunk -68_-52_-66_-50 in 50S_070W: 20240607_17_27_42
# Requesting data in chunk 40_2_42_4 in 10N_040E: 20240607_17_27_42
# Requesting data in chunk 12_64_14_66 in 70N_010E: 20240607_17_27_43
# Requesting data in chunk -108_-26_-106_-24 in 20S_110W: 20240607_17_27_47
# Requesting data in chunk 160_-10_162_-8 in 00N_160E: 20240607_17_27_50
# Requesting data in chunk 22_42_24_44 in 50N_020E: 20240607_17_27_34
# Requesting data in chunk -6_38_-4_40 in 40N_010W: 20240607_17_27_34
# Requesting data in chunk 90_28_92_30 in 30N_090E: 20240607_17_27_34
# Requesting data in chunk -64_48_-62_50 in 50N_070W: 20240607_17_27_51
# Requesting data in chunk 54_-14_56_-12 in 10S_050E: 20240607_17_27_48
# Requesting data in chunk -88_54_-86_56 in 60N_090W: 20240607_17_27_47
# Requesting data in chunk 134_34_136_36 in 40N_130E: 20240607_17_27_55
# Requesting data in chunk 98_70_100_72 in 80N_090E: 20240607_17_27_31
# Requesting data in chunk 110_54_112_56 in 60N_110E: 20240607_17_27_31
# Requesting data in chunk -68_-4_-66_-2 in 00N_070W: 20240607_17_27_31
# Requesting data in chunk 40_26_42_28 in 30N_040E: 20240607_17_27_31
# Requesting data in chunk 54_56_56_58 in 60N_050E: 20240607_17_27_56
# Requesting data in chunk 32_44_34_46 in 50N_030E: 20240607_17_28_00
# Requesting data in chunk 96_-2_98_0 in 00N_090E: 20240607_17_28_01
# CPU times: user 11.1 s, sys: 1.8 s, total: 12.9 s
# Wall time: 12min 43s
# (None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...)

# %%
### questions
# Tile id ses_2020 exists. Proceeding.

# %%
# local_client.shutdown()

# %%
# # Example data for testing
# in_dict_uint8 = {
#     'peat': np.random.randint(0, 2, size=(100, 100)).astype(np.uint8),
#     'land_cover_2020': np.random.randint(0, 10, size=(100, 100)).astype(np.uint8),
#     'planted_forest_type': np.random.randint(0, 2, size=(100, 100)).astype(np.uint8),
# }
# in_dict_int16 = {}
# in_dict_float32 = {
#     'dadap': np.random.rand(100, 100).astype(np.float32),
#     'osm_roads': np.random.rand(100, 100).astype(np.float32),
#     'osm_canals': np.random.rand(100, 100).astype(np.float32),
#     'engert': np.random.rand(100, 100).astype(np.float32),
#     'grip': np.random.rand(100, 100).astype(np.float32),
# }
# Out:
# 2024-06-07 11:55:20,626 - distributed.client - ERROR - Failed to reconnect to scheduler after 30.00 seconds, closing client
# 2024-06-07 17:13:40,482 - INFO - Found credentials in shared credentials file: ~/.aws/credentials
